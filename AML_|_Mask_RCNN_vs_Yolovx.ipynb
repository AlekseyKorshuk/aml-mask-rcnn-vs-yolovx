# %% [markdown]
# # Mask RCNN with Detectron2
#
# This tutorial is based on the [Detectron2 repository](https://github.com/facebookresearch/detectron2) by Facebook. This notebook shows training on **your own custom instance segmentation objects**.
#
# ### Accompanying Blog Post
#
# We recommend that you follow along in this notebook while reading the blog post on [how to train Detectron2 for custom instance segmentation](https://blog.roboflow.ai/custom-detectron2-instance-segmentation/), concurrently.
#
# ### Steps Covered in this Tutorial
#
# In this tutorial, we will walk through the steps required to train Detectron2 on your custom instance segmentation objects. We use a public [American Sign Language instance segmentation dataset](https://public.roboflow.ai/object-detection/bccd), which is open source and free to use. You can also use this notebook on your own data.
#
# To train our segmenter we take the following steps:
#
# * Install Detectron2 dependencies
# * Download custom instance segmentation data from Roboflow
# * Visualize Detectron2 training data
# * Write our Detectron2 Training configuration
# * Run Detectron2 training
# * Evaluate Dectron2 performance
# * Run Detectron2 inference on test images
# * Export saved Detectron2 weights for future inference
#
# ### **About**
#
# [Roboflow](https://roboflow.com) enables teams to deploy custom computer vision models quickly and accurately. Convert data from to annotation format, assess dataset health, preprocess, augment, and more. It's free for your first 1000 source images.
#
# **Looking for a vision model available via API without hassle? Try Roboflow Train.**
#
# ![Roboflow Wordmark](https://i.imgur.com/dcLNMhV.png)

# %% [markdown]
# ## Install Roboflow and Detectron2 Pip Packages, Import Deps

# %%
# !python -m pip install roboflow
# !python -m pip install 'git+https://github.com/facebookresearch/detectron2.git'
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting roboflow
#   Downloading roboflow-1.0.5-py3-none-any.whl (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.2/56.2 kB 2.4 MB/s eta 0:00:00
# Requirement already satisfied: urllib3>=1.26.6 in /usr/local/lib/python3.9/dist-packages (from roboflow) (1.26.15)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.9/dist-packages (from roboflow) (2.8.2)
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.9/dist-packages (from roboflow) (4.65.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from roboflow) (2.27.1)
# Requirement already satisfied: chardet==4.0.0 in /usr/local/lib/python3.9/dist-packages (from roboflow) (4.0.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.9/dist-packages (from roboflow) (1.4.4)
# Collecting python-dotenv
#   Downloading python_dotenv-1.0.0-py3-none-any.whl (19 kB)
# Collecting pyparsing==2.4.7
#   Downloading pyparsing-2.4.7-py2.py3-none-any.whl (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 4.7 MB/s eta 0:00:00
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/local/lib/python3.9/dist-packages (from roboflow) (6.0)
# Requirement already satisfied: certifi==2022.12.7 in /usr/local/lib/python3.9/dist-packages (from roboflow) (2022.12.7)
# Collecting wget
#   Downloading wget-3.2.zip (10 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: Pillow>=7.1.2 in /usr/local/lib/python3.9/dist-packages (from roboflow) (8.4.0)
# Requirement already satisfied: opencv-python>=4.1.2 in /usr/local/lib/python3.9/dist-packages (from roboflow) (4.7.0.72)
# Collecting requests-toolbelt
#   Downloading requests_toolbelt-0.10.1-py2.py3-none-any.whl (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 5.2 MB/s eta 0:00:00
# Requirement already satisfied: six in /usr/local/lib/python3.9/dist-packages (from roboflow) (1.16.0)
# Collecting idna==2.10
#   Downloading idna-2.10-py2.py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 6.2 MB/s eta 0:00:00
# Collecting cycler==0.10.0
#   Downloading cycler-0.10.0-py2.py3-none-any.whl (6.5 kB)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.9/dist-packages (from roboflow) (1.22.4)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.9/dist-packages (from roboflow) (3.7.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->roboflow) (4.39.3)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->roboflow) (23.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->roboflow) (1.0.7)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->roboflow) (5.12.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->roboflow) (2.0.12)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.9/dist-packages (from importlib-resources>=3.2.0->matplotlib->roboflow) (3.15.0)
# Building wheels for collected packages: wget
#   Building wheel for wget (setup.py) ... done
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9676 sha256=34e9348a75c6cabae0a8adfe35d3f9bf03a132cd6843ac37b51290949c9a7d9c
#   Stored in directory: /root/.cache/pip/wheels/04/5f/3e/46cc37c5d698415694d83f607f833f83f0149e49b3af9d0f38
# Successfully built wget
# Installing collected packages: wget, python-dotenv, pyparsing, idna, cycler, requests-toolbelt, roboflow
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.0.9
#     Uninstalling pyparsing-3.0.9:
#       Successfully uninstalled pyparsing-3.0.9
#   Attempting uninstall: idna
#     Found existing installation: idna 3.4
#     Uninstalling idna-3.4:
#       Successfully uninstalled idna-3.4
#   Attempting uninstall: cycler
#     Found existing installation: cycler 0.11.0
#     Uninstalling cycler-0.11.0:
#       Successfully uninstalled cycler-0.11.0
# Successfully installed cycler-0.10.0 idna-2.10 pyparsing-2.4.7 python-dotenv-1.0.0 requests-toolbelt-0.10.1 roboflow-1.0.5 wget-3.2
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting git+https://github.com/facebookresearch/detectron2.git
#   Cloning https://github.com/facebookresearch/detectron2.git to /tmp/pip-req-build-jsv1011h
#   Running command git clone --filter=blob:none --quiet https://github.com/facebookresearch/detectron2.git /tmp/pip-req-build-jsv1011h
#   Resolved https://github.com/facebookresearch/detectron2.git to commit ecb786ccd26de4086a6fede437e7d728199470e2
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: Pillow>=7.1 in /usr/local/lib/python3.9/dist-packages (from detectron2==0.6) (8.4.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.9/dist-packages (from detectron2==0.6) (3.7.1)
# Requirement already satisfied: pycocotools>=2.0.2 in /usr/local/lib/python3.9/dist-packages (from detectron2==0.6) (2.0.6)
# Requirement already satisfied: termcolor>=1.1 in /usr/local/lib/python3.9/dist-packages (from detectron2==0.6) (2.3.0)
# Collecting yacs>=0.1.8
#   Downloading yacs-0.1.8-py3-none-any.whl (14 kB)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.9/dist-packages (from detectron2==0.6) (0.8.10)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.9/dist-packages (from detectron2==0.6) (2.2.1)
# Requirement already satisfied: tqdm>4.29.0 in /usr/local/lib/python3.9/dist-packages (from detectron2==0.6) (4.65.0)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.9/dist-packages (from detectron2==0.6) (2.12.2)
# Collecting fvcore<0.1.6,>=0.1.5
#   Downloading fvcore-0.1.5.post20221221.tar.gz (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 4.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting iopath<0.1.10,>=0.1.7
#   Downloading iopath-0.1.9-py3-none-any.whl (27 kB)
# Collecting omegaconf>=2.1
#   Downloading omegaconf-2.3.0-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 10.4 MB/s eta 0:00:00
# Collecting hydra-core>=1.1
#   Downloading hydra_core-1.3.2-py3-none-any.whl (154 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 20.4 MB/s eta 0:00:00
# Collecting black
#   Downloading black-23.3.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 62.0 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from detectron2==0.6) (23.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from fvcore<0.1.6,>=0.1.5->detectron2==0.6) (1.22.4)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.9/dist-packages (from fvcore<0.1.6,>=0.1.5->detectron2==0.6) (6.0)
# Collecting antlr4-python3-runtime==4.9.*
#   Downloading antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 14.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting portalocker
#   Downloading portalocker-2.7.0-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->detectron2==0.6) (2.4.7)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->detectron2==0.6) (5.12.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib->detectron2==0.6) (0.10.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.9/dist-packages (from matplotlib->detectron2==0.6) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->detectron2==0.6) (1.4.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->detectron2==0.6) (1.0.7)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->detectron2==0.6) (4.39.3)
# Requirement already satisfied: tomli>=1.1.0 in /usr/local/lib/python3.9/dist-packages (from black->detectron2==0.6) (2.0.1)
# Collecting mypy-extensions>=0.4.3
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Collecting pathspec>=0.9.0
#   Downloading pathspec-0.11.1-py3-none-any.whl (29 kB)
# Requirement already satisfied: platformdirs>=2 in /usr/local/lib/python3.9/dist-packages (from black->detectron2==0.6) (3.2.0)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.9/dist-packages (from black->detectron2==0.6) (8.1.3)
# Requirement already satisfied: typing-extensions>=3.10.0.0 in /usr/local/lib/python3.9/dist-packages (from black->detectron2==0.6) (4.5.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.9/dist-packages (from tensorboard->detectron2==0.6) (1.4.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard->detectron2==0.6) (0.7.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.9/dist-packages (from tensorboard->detectron2==0.6) (2.17.3)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard->detectron2==0.6) (67.7.2)
# Requirement already satisfied: protobuf>=3.19.6 in /usr/local/lib/python3.9/dist-packages (from tensorboard->detectron2==0.6) (3.20.3)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.9/dist-packages (from tensorboard->detectron2==0.6) (3.4.3)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.9/dist-packages (from tensorboard->detectron2==0.6) (0.40.0)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from tensorboard->detectron2==0.6) (2.2.3)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.9/dist-packages (from tensorboard->detectron2==0.6) (1.54.0)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard->detectron2==0.6) (2.27.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard->detectron2==0.6) (1.8.1)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.9/dist-packages (from tensorboard->detectron2==0.6) (1.0.0)
# Requirement already satisfied: six in /usr/local/lib/python3.9/dist-packages (from cycler>=0.10->matplotlib->detectron2==0.6) (1.16.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard->detectron2==0.6) (0.3.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard->detectron2==0.6) (5.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard->detectron2==0.6) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.9/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard->detectron2==0.6) (1.3.1)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.9/dist-packages (from importlib-resources>=3.2.0->matplotlib->detectron2==0.6) (3.15.0)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.9/dist-packages (from markdown>=2.6.8->tensorboard->detectron2==0.6) (6.6.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.21.0->tensorboard->detectron2==0.6) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.21.0->tensorboard->detectron2==0.6) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.21.0->tensorboard->detectron2==0.6) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.21.0->tensorboard->detectron2==0.6) (2022.12.7)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.9/dist-packages (from werkzeug>=1.0.1->tensorboard->detectron2==0.6) (2.1.2)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.9/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard->detectron2==0.6) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.9/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard->detectron2==0.6) (3.2.2)
# Building wheels for collected packages: detectron2, fvcore, antlr4-python3-runtime
#   Building wheel for detectron2 (setup.py) ... done
#   Created wheel for detectron2: filename=detectron2-0.6-cp39-cp39-linux_x86_64.whl size=7802362 sha256=25ab95cd9e7ecd08b805d551b1fc6db1dce5dc97703be330df8f1c67124f3fa1
#   Stored in directory: /tmp/pip-ephem-wheel-cache-p2zf0m6n/wheels/59/b4/83/84bfca751fa4dcc59998468be8688eb50e97408a83af171d42
#   Building wheel for fvcore (setup.py) ... done
#   Created wheel for fvcore: filename=fvcore-0.1.5.post20221221-py3-none-any.whl size=61429 sha256=77f1764f07753976d0bbe0f50d92b4747c558f26d087ac4ceec71aa4e56f2ef1
#   Stored in directory: /root/.cache/pip/wheels/83/42/02/66178d16e5c44dc26d309931834956baeda371956e86fbd876
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144573 sha256=85b218b7167610fadb762654f1339746d79608264b1dce28c64b2f2a8e10cabc
#   Stored in directory: /root/.cache/pip/wheels/23/cf/80/f3efa822e6ab23277902ee9165fe772eeb1dfb8014f359020a
# Successfully built detectron2 fvcore antlr4-python3-runtime
# Installing collected packages: antlr4-python3-runtime, yacs, portalocker, pathspec, omegaconf, mypy-extensions, iopath, hydra-core, black, fvcore, detectron2
# Successfully installed antlr4-python3-runtime-4.9.3 black-23.3.0 detectron2-0.6 fvcore-0.1.5.post20221221 hydra-core-1.3.2 iopath-0.1.9 mypy-extensions-1.0.0 omegaconf-2.3.0 pathspec-0.11.1 portalocker-2.7.0 yacs-0.1.8

# %%
import logging
import torch
from collections import OrderedDict
import detectron2
from detectron2.utils.logger import setup_logger
setup_logger()

# import some common libraries
import numpy as np
import os, json, cv2, random

# import some common detectron2 utilities
from detectron2 import model_zoo
from detectron2.engine import DefaultPredictor
from detectron2.config import get_cfg
from detectron2.utils.visualizer import Visualizer
from detectron2.data import MetadataCatalog, DatasetCatalog
from detectron2.data.datasets import register_coco_instances
from detectron2.engine import DefaultTrainer
from detectron2.utils.visualizer import ColorMode
from detectron2.solver import build_lr_scheduler, build_optimizer
from detectron2.checkpoint import DetectionCheckpointer, PeriodicCheckpointer
from detectron2.utils.events import EventStorage
from detectron2.modeling import build_model
import detectron2.utils.comm as comm
from detectron2.engine import default_argument_parser, default_setup, default_writers, launch
from detectron2.data import (
    MetadataCatalog,
    build_detection_test_loader,
    build_detection_train_loader,
)
from detectron2.evaluation import (
    CityscapesInstanceEvaluator,
    CityscapesSemSegEvaluator,
    COCOEvaluator,
    COCOPanopticEvaluator,
    DatasetEvaluators,
    LVISEvaluator,
    PascalVOCDetectionEvaluator,
    SemSegEvaluator,
    inference_on_dataset,
    print_csv_format,
)

from roboflow import Roboflow

from matplotlib import pyplot as plt
from PIL import Image

# %% [markdown]
# ## Download dataset via Roboflow pip package and show a sample annotation

# %%
# !curl -L "https://app.roboflow.com/ds/52ZxLquiy6?key=WzuySy9x2y" > roboflow.zip; unzip roboflow.zip; rm roboflow.zip

# %%
VERSION = 2
rf = Roboflow(api_key="YOUR API KEY HERE")
project = rf.workspace("team-roboflow").project("american-sign-language-poly")
dataset = project.version(VERSION).download("coco")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in American-Sign-Language-Poly-2 to coco: 100% [58281839 / 58281839] bytes
# Extracting Dataset Version Zip to American-Sign-Language-Poly-2 in coco:: 100%|██████████| 1679/1679 [00:01<00:00, 898.14it/s]

# %%
register_coco_instances("asl_poly_train", {}, f"/content/train/_annotations.coco.json", f"/content/train/")
register_coco_instances("asl_poly_valid", {}, f"/content/valid/_annotations.coco.json", f"/content/valid/")
register_coco_instances("asl_poly_test", {}, f"/content/test/_annotations.coco.json", f"/content/test/")

# %%
dataset_train = DatasetCatalog.get("asl_poly_train")
fig, ax = plt.subplots()
dataset_dict = random.choice(dataset_train)
im = Image.open(dataset_dict['file_name'])
ax.imshow(im)
for ann in dataset_dict['annotations']:
    for poly in ann['segmentation']:
        x = poly[0::2]
        y = poly[1::2]
        ax.plot(x,y, linewidth=2, color='red')
# Out:
# WARNING [04/27 05:39:55 d2.data.datasets.coco]:
# Category ids in annotations are not in [1, #categories]! We'll apply a mapping for you.
#
# [04/27 05:39:55 d2.data.datasets.coco]: Loaded 219 images in COCO format from /content/train/_annotations.coco.json

# %% [markdown]
# ## Configure Detectron2 for fine tuning from COCO, Define training loop helper functions (from detectron2 repo), Run custom training loop

# %%
cfg = get_cfg()
cfg.merge_from_file(model_zoo.get_config_file("COCO-InstanceSegmentation/mask_rcnn_R_50_FPN_3x.yaml"))
cfg.DATASETS.TRAIN = ("asl_poly_train",)#Train dataset registered in a previous cell
cfg.DATASETS.TEST = ("asl_poly_test",)#Test dataset registered in a previous cell
cfg.DATALOADER.NUM_WORKERS = 2
cfg.MODEL.WEIGHTS = model_zoo.get_checkpoint_url("COCO-InstanceSegmentation/mask_rcnn_R_50_FPN_3x.yaml")  # Let training initialize from model zoo
cfg.SOLVER.IMS_PER_BATCH = 2
cfg.SOLVER.BASE_LR = 0.00025
cfg.SOLVER.MAX_ITER = 10000 #We found that with a patience of 500, training will early stop before 10,000 iterations
cfg.SOLVER.STEPS = []
cfg.MODEL.ROI_HEADS.BATCH_SIZE_PER_IMAGE = 512
cfg.MODEL.ROI_HEADS.NUM_CLASSES = 27 # 26 letters plus one super class
cfg.TEST.EVAL_PERIOD = 0 # Increase this number if you want to monitor validation performance during training

PATIENCE = 500 #Early stopping will occur after N iterations of no imporovement in total_loss

os.makedirs(cfg.OUTPUT_DIR, exist_ok=True)

# %%
def get_evaluator(cfg, dataset_name, output_folder=None):
    """
    Create evaluator(s) for a given dataset.
    This uses the special metadata "evaluator_type" associated with each builtin dataset.
    For your own dataset, you can simply create an evaluator manually in your
    script and do not have to worry about the hacky if-else logic here.
    """
    if output_folder is None:
        output_folder = os.path.join(cfg.OUTPUT_DIR, "inference")
    evaluator_list = []
    evaluator_type = MetadataCatalog.get(dataset_name).evaluator_type
    if evaluator_type in ["sem_seg", "coco_panoptic_seg"]:
        evaluator_list.append(
            SemSegEvaluator(
                dataset_name,
                distributed=True,
                output_dir=output_folder,
            )
        )
    if evaluator_type in ["coco", "coco_panoptic_seg"]:
        evaluator_list.append(COCOEvaluator(dataset_name, output_dir=output_folder))
    if evaluator_type == "coco_panoptic_seg":
        evaluator_list.append(COCOPanopticEvaluator(dataset_name, output_folder))
    if evaluator_type == "cityscapes_instance":
        return CityscapesInstanceEvaluator(dataset_name)
    if evaluator_type == "cityscapes_sem_seg":
        return CityscapesSemSegEvaluator(dataset_name)
    if evaluator_type == "pascal_voc":
        return PascalVOCDetectionEvaluator(dataset_name)
    if evaluator_type == "lvis":
        return LVISEvaluator(dataset_name, cfg, True, output_folder)
    if len(evaluator_list) == 0:
        raise NotImplementedError(
            "no Evaluator for the dataset {} with the type {}".format(dataset_name, evaluator_type)
        )
    if len(evaluator_list) == 1:
        return evaluator_list[0]
    return DatasetEvaluators(evaluator_list)

def do_test(cfg, model):
    results = OrderedDict()
    for dataset_name in cfg.DATASETS.TEST:
        data_loader = build_detection_test_loader(cfg, dataset_name)
        evaluator = get_evaluator(
            cfg, dataset_name, os.path.join(cfg.OUTPUT_DIR, "inference", dataset_name)
        )
        results_i = inference_on_dataset(model, data_loader, evaluator)
        results[dataset_name] = results_i
        if comm.is_main_process():
            logger.info("Evaluation results for {} in csv format:".format(dataset_name))
            print_csv_format(results_i)
    if len(results) == 1:
        results = list(results.values())[0]
    return results


logger = logging.getLogger("detectron2")
resume=False
model = build_model(cfg)
optimizer = build_optimizer(cfg, model)
scheduler = build_lr_scheduler(cfg, optimizer)

BEST_LOSS = np.inf

checkpointer = DetectionCheckpointer(
    model, cfg.OUTPUT_DIR, optimizer=optimizer, scheduler=scheduler
)
start_iter = (
    checkpointer.resume_or_load(cfg.MODEL.WEIGHTS, resume=resume).get("iteration", -1) + 1
)
prev_iter = start_iter
max_iter = cfg.SOLVER.MAX_ITER

periodic_checkpointer = PeriodicCheckpointer(
    checkpointer, cfg.SOLVER.CHECKPOINT_PERIOD, max_iter=max_iter
)

writers = default_writers(cfg.OUTPUT_DIR, max_iter) if comm.is_main_process() else []

# compared to "train_net.py", we do not support accurate timing and
# precise BN here, because they are not trivial to implement in a small training loop
data_loader = build_detection_train_loader(cfg)
logger.info("Starting training from iteration {}".format(start_iter))
patience_counter = 0
with EventStorage(start_iter) as storage:
    for data, iteration in zip(data_loader, range(start_iter, max_iter)):
        storage.iter = iteration

        loss_dict = model(data)
        losses = sum(loss_dict.values())
        assert torch.isfinite(losses).all(), loss_dict

        loss_dict_reduced = {k: v.item() for k, v in comm.reduce_dict(loss_dict).items()}
        losses_reduced = sum(loss for loss in loss_dict_reduced.values())
        if comm.is_main_process():
            storage.put_scalars(total_loss=losses_reduced, **loss_dict_reduced)

        optimizer.zero_grad()
        losses.backward()
        optimizer.step()
        storage.put_scalar("lr", optimizer.param_groups[0]["lr"], smoothing_hint=False)
        scheduler.step()

        if (
            cfg.TEST.EVAL_PERIOD > 0
            and (iteration + 1) % cfg.TEST.EVAL_PERIOD == 0
            and iteration != max_iter - 1
        ):
            do_test(cfg, model)
            # Compared to "train_net.py", the test results are not dumped to EventStorage
            comm.synchronize()

        if iteration - start_iter > 5 and (
            (iteration + 1) % 20 == 0 or iteration == max_iter - 1
        ):
            for writer in writers:
                writer.write()
        periodic_checkpointer.step(iteration)
        
        if iteration > prev_iter:
            prev_iter = iteration
            if losses_reduced < BEST_LOSS:
                BEST_LOSS = losses_reduced
                patience_counter = 0
            else:
                patience_counter += 1
                if patience_counter % 100 == 0:
                    print(f"Loss has not improved for {patience_counter} iterations")
                if patience_counter >= PATIENCE:
                    print(f"EARLY STOPPING")
                    break
                
do_test(cfg, model)
# Out:
# [04/27 05:40:07 d2.checkpoint.detection_checkpoint]: [DetectionCheckpointer] Loading from https://dl.fbaipublicfiles.com/detectron2/COCO-InstanceSegmentation/mask_rcnn_R_50_FPN_3x/137849600/model_final_f10217.pkl ...
# model_final_f10217.pkl: 178MB [00:01, 173MB/s]
# WARNING:fvcore.common.checkpoint:Skip loading parameter 'roi_heads.box_predictor.cls_score.weight' to the model due to incompatible shapes: (81, 1024) in the checkpoint but (28, 1024) in the model! You might want to double check if this is expected.
# WARNING:fvcore.common.checkpoint:Skip loading parameter 'roi_heads.box_predictor.cls_score.bias' to the model due to incompatible shapes: (81,) in the checkpoint but (28,) in the model! You might want to double check if this is expected.
# WARNING:fvcore.common.checkpoint:Skip loading parameter 'roi_heads.box_predictor.bbox_pred.weight' to the model due to incompatible shapes: (320, 1024) in the checkpoint but (108, 1024) in the model! You might want to double check if this is expected.
# WARNING:fvcore.common.checkpoint:Skip loading parameter 'roi_heads.box_predictor.bbox_pred.bias' to the model due to incompatible shapes: (320,) in the checkpoint but (108,) in the model! You might want to double check if this is expected.
# WARNING:fvcore.common.checkpoint:Skip loading parameter 'roi_heads.mask_head.predictor.weight' to the model due to incompatible shapes: (80, 256, 1, 1) in the checkpoint but (27, 256, 1, 1) in the model! You might want to double check if this is expected.
# WARNING:fvcore.common.checkpoint:Skip loading parameter 'roi_heads.mask_head.predictor.bias' to the model due to incompatible shapes: (80,) in the checkpoint but (27,) in the model! You might want to double check if this is expected.
# WARNING:fvcore.common.checkpoint:Some model parameters or buffers are not found in the checkpoint:
# roi_heads.box_predictor.bbox_pred.{bias, weight}
# roi_heads.box_predictor.cls_score.{bias, weight}
# roi_heads.mask_head.predictor.{bias, weight}
# WARNING [04/27 05:40:09 d2.data.datasets.coco]:
# Category ids in annotations are not in [1, #categories]! We'll apply a mapping for you.
#
# [04/27 05:40:09 d2.data.datasets.coco]: Loaded 219 images in COCO format from /content/train/_annotations.coco.json
# [04/27 05:40:09 d2.data.build]: Removed 0 images with no usable annotations. 219 images left.
# [04/27 05:40:09 d2.data.build]: Distribution of instances among all 3 categories:
# |  category  | #instances   |  category  | #instances   |  category  | #instances   |
# |:----------:|:-------------|:----------:|:-------------|:----------:|:-------------|
# | spoon-fox  | 0            |    fox     | 168          |   spoon    | 153          |
# |            |              |            |              |            |              |
# |   total    | 321          |            |              |            |              |
# [04/27 05:40:09 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in training: [ResizeShortestEdge(short_edge_length=(640, 672, 704, 736, 768, 800), max_size=1333, sample_style='choice'), RandomFlip()]
# [04/27 05:40:09 d2.data.build]: Using training sampler TrainingSampler
# [04/27 05:40:09 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [04/27 05:40:09 d2.data.common]: Serializing 219 elements to byte tensors and concatenating them all ...
# [04/27 05:40:09 d2.data.common]: Serialized dataset takes 0.14 MiB
# [04/27 05:40:09 detectron2]: Starting training from iteration 0
# torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3483.)
# [04/27 05:40:20 d2.utils.events]:  iter: 19  total_loss: 4.244  loss_cls: 3.413  loss_box_reg: 0.05038  loss_mask: 0.6931  loss_rpn_cls: 0.02633  loss_rpn_loc: 0.01849     lr: 4.9953e-06  max_mem: 1767M
# [04/27 05:40:30 d2.utils.events]:  eta: 1:23:36  iter: 39  total_loss: 4.065  loss_cls: 3.206  loss_box_reg: 0.09005  loss_mask: 0.69  loss_rpn_cls: 0.02555  loss_rpn_loc: 0.0163     lr: 9.9902e-06  max_mem: 1769M
# [04/27 05:40:37 d2.utils.events]:  eta: 0:55:47  iter: 59  total_loss: 3.62  loss_cls: 2.826  loss_box_reg: 0.08533  loss_mask: 0.6843  loss_rpn_cls: 0.03434  loss_rpn_loc: 0.02029     lr: 1.4985e-05  max_mem: 1771M
# [04/27 05:40:44 d2.utils.events]:  eta: 0:54:52  iter: 79  total_loss: 2.933  loss_cls: 2.06  loss_box_reg: 0.09138  loss_mask: 0.6739  loss_rpn_cls: 0.03816  loss_rpn_loc: 0.01283     lr: 1.998e-05  max_mem: 1771M
# [04/27 05:40:51 d2.utils.events]:  eta: 0:58:00  iter: 99  total_loss: 1.928  loss_cls: 1.082  loss_box_reg: 0.08391  loss_mask: 0.6593  loss_rpn_cls: 0.02183  loss_rpn_loc: 0.01507     lr: 2.4975e-05  max_mem: 1771M
# [04/27 05:40:57 d2.utils.events]:  eta: 0:54:48  iter: 119  total_loss: 1.199  loss_cls: 0.3422  loss_box_reg: 0.1049  loss_mask: 0.6592  loss_rpn_cls: 0.04032  loss_rpn_loc: 0.01596     lr: 2.997e-05  max_mem: 1771M
# [04/27 05:41:04 d2.utils.events]:  eta: 0:55:00  iter: 139  total_loss: 0.9823  loss_cls: 0.1946  loss_box_reg: 0.085  loss_mask: 0.6359  loss_rpn_cls: 0.05486  loss_rpn_loc: 0.0202     lr: 3.4965e-05  max_mem: 1771M
# [04/27 05:41:11 d2.utils.events]:  eta: 0:55:26  iter: 159  total_loss: 1  loss_cls: 0.1697  loss_box_reg: 0.06391  loss_mask: 0.6197  loss_rpn_cls: 0.04046  loss_rpn_loc: 0.0183     lr: 3.996e-05  max_mem: 1771M
# [04/27 05:41:18 d2.utils.events]:  eta: 0:55:38  iter: 179  total_loss: 1.001  loss_cls: 0.2411  loss_box_reg: 0.1242  loss_mask: 0.5848  loss_rpn_cls: 0.01438  loss_rpn_loc: 0.0157     lr: 4.4955e-05  max_mem: 1771M
# [04/27 05:41:25 d2.utils.events]:  eta: 1:00:13  iter: 199  total_loss: 0.9309  loss_cls: 0.2094  loss_box_reg: 0.1055  loss_mask: 0.5752  loss_rpn_cls: 0.02235  loss_rpn_loc: 0.01594     lr: 4.995e-05  max_mem: 1771M
# [04/27 05:41:33 d2.utils.events]:  eta: 1:03:21  iter: 219  total_loss: 0.8267  loss_cls: 0.1821  loss_box_reg: 0.09377  loss_mask: 0.5388  loss_rpn_cls: 0.01532  loss_rpn_loc: 0.01442     lr: 5.4945e-05  max_mem: 1771M
# [04/27 05:41:40 d2.utils.events]:  eta: 0:57:27  iter: 239  total_loss: 0.7579  loss_cls: 0.1649  loss_box_reg: 0.09382  loss_mask: 0.493  loss_rpn_cls: 0.01501  loss_rpn_loc: 0.01495     lr: 5.994e-05  max_mem: 1771M
# [04/27 05:41:47 d2.utils.events]:  eta: 0:57:17  iter: 259  total_loss: 0.8092  loss_cls: 0.1689  loss_box_reg: 0.1092  loss_mask: 0.4486  loss_rpn_cls: 0.01794  loss_rpn_loc: 0.0156     lr: 6.4935e-05  max_mem: 1771M
# [04/27 05:41:54 d2.utils.events]:  eta: 0:55:50  iter: 279  total_loss: 0.8774  loss_cls: 0.1949  loss_box_reg: 0.0966  loss_mask: 0.4871  loss_rpn_cls: 0.02339  loss_rpn_loc: 0.01137     lr: 6.993e-05  max_mem: 1771M
# [04/27 05:42:01 d2.utils.events]:  eta: 0:58:07  iter: 299  total_loss: 0.6931  loss_cls: 0.1687  loss_box_reg: 0.1068  loss_mask: 0.4062  loss_rpn_cls: 0.01499  loss_rpn_loc: 0.01234     lr: 7.4925e-05  max_mem: 1771M
# [04/27 05:42:08 d2.utils.events]:  eta: 0:58:39  iter: 319  total_loss: 0.7018  loss_cls: 0.1942  loss_box_reg: 0.1164  loss_mask: 0.3716  loss_rpn_cls: 0.01378  loss_rpn_loc: 0.01197     lr: 7.992e-05  max_mem: 1771M
# [04/27 05:42:16 d2.utils.events]:  eta: 1:00:37  iter: 339  total_loss: 0.6347  loss_cls: 0.1707  loss_box_reg: 0.1246  loss_mask: 0.3148  loss_rpn_cls: 0.009765  loss_rpn_loc: 0.01045     lr: 8.4915e-05  max_mem: 1771M
# [04/27 05:42:23 d2.utils.events]:  eta: 0:58:35  iter: 359  total_loss: 0.6695  loss_cls: 0.1793  loss_box_reg: 0.1312  loss_mask: 0.3334  loss_rpn_cls: 0.01554  loss_rpn_loc: 0.01589     lr: 8.991e-05  max_mem: 1771M
# [04/27 05:42:30 d2.utils.events]:  eta: 0:54:59  iter: 379  total_loss: 0.6228  loss_cls: 0.1601  loss_box_reg: 0.1242  loss_mask: 0.2882  loss_rpn_cls: 0.01315  loss_rpn_loc: 0.01174     lr: 9.4905e-05  max_mem: 1771M
# [04/27 05:42:37 d2.utils.events]:  eta: 0:58:48  iter: 399  total_loss: 0.5938  loss_cls: 0.1577  loss_box_reg: 0.1374  loss_mask: 0.2606  loss_rpn_cls: 0.008138  loss_rpn_loc: 0.01413     lr: 9.99e-05  max_mem: 1771M
# [04/27 05:42:45 d2.utils.events]:  eta: 0:59:19  iter: 419  total_loss: 0.5924  loss_cls: 0.1734  loss_box_reg: 0.1659  loss_mask: 0.2487  loss_rpn_cls: 0.01328  loss_rpn_loc: 0.01365     lr: 0.0001049  max_mem: 1771M
# [04/27 05:42:53 d2.utils.events]:  eta: 1:01:41  iter: 439  total_loss: 0.5384  loss_cls: 0.1461  loss_box_reg: 0.1393  loss_mask: 0.2004  loss_rpn_cls: 0.0114  loss_rpn_loc: 0.01324     lr: 0.00010989  max_mem: 1771M
# [04/27 05:43:00 d2.utils.events]:  eta: 0:58:16  iter: 459  total_loss: 0.4954  loss_cls: 0.1356  loss_box_reg: 0.1512  loss_mask: 0.1986  loss_rpn_cls: 0.009221  loss_rpn_loc: 0.01126     lr: 0.00011489  max_mem: 1771M
# [04/27 05:43:08 d2.utils.events]:  eta: 1:00:47  iter: 479  total_loss: 0.4626  loss_cls: 0.1046  loss_box_reg: 0.1161  loss_mask: 0.2001  loss_rpn_cls: 0.008059  loss_rpn_loc: 0.01476     lr: 0.00011988  max_mem: 1771M
# [04/27 05:43:15 d2.utils.events]:  eta: 0:58:45  iter: 499  total_loss: 0.533  loss_cls: 0.1501  loss_box_reg: 0.1653  loss_mask: 0.1877  loss_rpn_cls: 0.008709  loss_rpn_loc: 0.01189     lr: 0.00012488  max_mem: 1771M
# [04/27 05:43:22 d2.utils.events]:  eta: 0:58:47  iter: 519  total_loss: 0.5034  loss_cls: 0.1162  loss_box_reg: 0.1462  loss_mask: 0.1921  loss_rpn_cls: 0.01178  loss_rpn_loc: 0.01455     lr: 0.00012987  max_mem: 1771M
# [04/27 05:43:30 d2.utils.events]:  eta: 0:58:44  iter: 539  total_loss: 0.5093  loss_cls: 0.1126  loss_box_reg: 0.1306  loss_mask: 0.2057  loss_rpn_cls: 0.003538  loss_rpn_loc: 0.01152     lr: 0.00013487  max_mem: 1771M
# [04/27 05:43:37 d2.utils.events]:  eta: 0:58:40  iter: 559  total_loss: 0.454  loss_cls: 0.1022  loss_box_reg: 0.1483  loss_mask: 0.2021  loss_rpn_cls: 0.005375  loss_rpn_loc: 0.01178     lr: 0.00013986  max_mem: 1771M
# [04/27 05:43:45 d2.utils.events]:  eta: 0:59:02  iter: 579  total_loss: 0.4425  loss_cls: 0.105  loss_box_reg: 0.1282  loss_mask: 0.181  loss_rpn_cls: 0.006289  loss_rpn_loc: 0.01195     lr: 0.00014486  max_mem: 1771M
# [04/27 05:43:52 d2.utils.events]:  eta: 0:57:46  iter: 599  total_loss: 0.4519  loss_cls: 0.1016  loss_box_reg: 0.1414  loss_mask: 0.167  loss_rpn_cls: 0.008071  loss_rpn_loc: 0.01202     lr: 0.00014985  max_mem: 1771M
# [04/27 05:43:59 d2.utils.events]:  eta: 0:56:33  iter: 619  total_loss: 0.3781  loss_cls: 0.1055  loss_box_reg: 0.1302  loss_mask: 0.1535  loss_rpn_cls: 0.007437  loss_rpn_loc: 0.00957     lr: 0.00015485  max_mem: 1771M
# [04/27 05:44:08 d2.utils.events]:  eta: 1:10:41  iter: 639  total_loss: 0.4636  loss_cls: 0.1053  loss_box_reg: 0.1394  loss_mask: 0.1818  loss_rpn_cls: 0.004135  loss_rpn_loc: 0.01241     lr: 0.00015984  max_mem: 1771M
# [04/27 05:44:16 d2.utils.events]:  eta: 0:56:37  iter: 659  total_loss: 0.3766  loss_cls: 0.08636  loss_box_reg: 0.1138  loss_mask: 0.168  loss_rpn_cls: 0.004109  loss_rpn_loc: 0.009867     lr: 0.00016484  max_mem: 1771M
# [04/27 05:44:23 d2.utils.events]:  eta: 0:57:55  iter: 679  total_loss: 0.4051  loss_cls: 0.09219  loss_box_reg: 0.1158  loss_mask: 0.174  loss_rpn_cls: 0.002837  loss_rpn_loc: 0.01153     lr: 0.00016983  max_mem: 1772M
# [04/27 05:44:31 d2.utils.events]:  eta: 0:59:34  iter: 699  total_loss: 0.4065  loss_cls: 0.09366  loss_box_reg: 0.1184  loss_mask: 0.1787  loss_rpn_cls: 0.003515  loss_rpn_loc: 0.008845     lr: 0.00017483  max_mem: 1772M
# [04/27 05:44:38 d2.utils.events]:  eta: 0:57:36  iter: 719  total_loss: 0.4281  loss_cls: 0.09487  loss_box_reg: 0.1139  loss_mask: 0.167  loss_rpn_cls: 0.01108  loss_rpn_loc: 0.01293     lr: 0.00017982  max_mem: 1772M
# [04/27 05:44:46 d2.utils.events]:  eta: 0:58:09  iter: 739  total_loss: 0.3379  loss_cls: 0.08845  loss_box_reg: 0.1019  loss_mask: 0.1503  loss_rpn_cls: 0.007293  loss_rpn_loc: 0.01091     lr: 0.00018482  max_mem: 1772M
# [04/27 05:44:53 d2.utils.events]:  eta: 0:57:39  iter: 759  total_loss: 0.3568  loss_cls: 0.08752  loss_box_reg: 0.09418  loss_mask: 0.165  loss_rpn_cls: 0.003495  loss_rpn_loc: 0.0093     lr: 0.00018981  max_mem: 1772M
# Loss has not improved for 100 iterations
# [04/27 05:45:01 d2.utils.events]:  eta: 1:00:07  iter: 779  total_loss: 0.3545  loss_cls: 0.08206  loss_box_reg: 0.1  loss_mask: 0.1319  loss_rpn_cls: 0.008839  loss_rpn_loc: 0.01119     lr: 0.00019481  max_mem: 1772M
# [04/27 05:45:08 d2.utils.events]:  eta: 0:54:55  iter: 799  total_loss: 0.376  loss_cls: 0.08071  loss_box_reg: 0.09564  loss_mask: 0.1788  loss_rpn_cls: 0.006562  loss_rpn_loc: 0.0116     lr: 0.0001998  max_mem: 1772M
# [04/27 05:45:16 d2.utils.events]:  eta: 0:58:01  iter: 819  total_loss: 0.3588  loss_cls: 0.09187  loss_box_reg: 0.1064  loss_mask: 0.1737  loss_rpn_cls: 0.004149  loss_rpn_loc: 0.008638     lr: 0.0002048  max_mem: 1772M
# [04/27 05:45:23 d2.utils.events]:  eta: 0:55:41  iter: 839  total_loss: 0.3004  loss_cls: 0.07111  loss_box_reg: 0.07254  loss_mask: 0.1506  loss_rpn_cls: 0.003827  loss_rpn_loc: 0.0108     lr: 0.00020979  max_mem: 1772M
# [04/27 05:45:31 d2.utils.events]:  eta: 0:55:50  iter: 859  total_loss: 0.3169  loss_cls: 0.0854  loss_box_reg: 0.08549  loss_mask: 0.1375  loss_rpn_cls: 0.005504  loss_rpn_loc: 0.01195     lr: 0.00021479  max_mem: 1772M
# [04/27 05:45:38 d2.utils.events]:  eta: 0:56:24  iter: 879  total_loss: 0.2701  loss_cls: 0.06146  loss_box_reg: 0.06038  loss_mask: 0.118  loss_rpn_cls: 0.001229  loss_rpn_loc: 0.009059     lr: 0.00021978  max_mem: 1772M
# [04/27 05:45:46 d2.utils.events]:  eta: 0:58:34  iter: 899  total_loss: 0.2858  loss_cls: 0.08484  loss_box_reg: 0.08698  loss_mask: 0.134  loss_rpn_cls: 0.00622  loss_rpn_loc: 0.0095     lr: 0.00022478  max_mem: 1772M
# [04/27 05:45:54 d2.utils.events]:  eta: 0:59:17  iter: 919  total_loss: 0.2996  loss_cls: 0.07527  loss_box_reg: 0.07366  loss_mask: 0.1399  loss_rpn_cls: 0.001642  loss_rpn_loc: 0.009314     lr: 0.00022977  max_mem: 1772M
# [04/27 05:46:01 d2.utils.events]:  eta: 0:57:33  iter: 939  total_loss: 0.3058  loss_cls: 0.07109  loss_box_reg: 0.083  loss_mask: 0.1458  loss_rpn_cls: 0.001334  loss_rpn_loc: 0.009241     lr: 0.00023477  max_mem: 1772M
# [04/27 05:46:09 d2.utils.events]:  eta: 1:00:32  iter: 959  total_loss: 0.296  loss_cls: 0.06827  loss_box_reg: 0.05954  loss_mask: 0.1559  loss_rpn_cls: 0.003159  loss_rpn_loc: 0.007327     lr: 0.00023976  max_mem: 1772M
# [04/27 05:46:17 d2.utils.events]:  eta: 0:56:16  iter: 979  total_loss: 0.3303  loss_cls: 0.08238  loss_box_reg: 0.07742  loss_mask: 0.1414  loss_rpn_cls: 0.002626  loss_rpn_loc: 0.008067     lr: 0.00024476  max_mem: 1772M
# [04/27 05:46:24 d2.utils.events]:  eta: 0:56:35  iter: 999  total_loss: 0.3031  loss_cls: 0.07473  loss_box_reg: 0.07645  loss_mask: 0.1411  loss_rpn_cls: 0.001618  loss_rpn_loc: 0.008921     lr: 0.00024975  max_mem: 1772M
# Loss has not improved for 100 iterations
# [04/27 05:46:32 d2.utils.events]:  eta: 0:55:07  iter: 1019  total_loss: 0.3092  loss_cls: 0.07007  loss_box_reg: 0.07459  loss_mask: 0.1416  loss_rpn_cls: 0.001052  loss_rpn_loc: 0.007568     lr: 0.00025  max_mem: 1772M
# [04/27 05:46:39 d2.utils.events]:  eta: 0:56:21  iter: 1039  total_loss: 0.3002  loss_cls: 0.07002  loss_box_reg: 0.07354  loss_mask: 0.1285  loss_rpn_cls: 0.001855  loss_rpn_loc: 0.007398     lr: 0.00025  max_mem: 1772M
# [04/27 05:46:47 d2.utils.events]:  eta: 0:55:41  iter: 1059  total_loss: 0.2703  loss_cls: 0.05648  loss_box_reg: 0.05652  loss_mask: 0.1506  loss_rpn_cls: 0.0005517  loss_rpn_loc: 0.009621     lr: 0.00025  max_mem: 1772M
# [04/27 05:46:54 d2.utils.events]:  eta: 0:56:36  iter: 1079  total_loss: 0.2774  loss_cls: 0.06916  loss_box_reg: 0.06871  loss_mask: 0.1445  loss_rpn_cls: 0.0004773  loss_rpn_loc: 0.006678     lr: 0.00025  max_mem: 1772M
# [04/27 05:47:02 d2.utils.events]:  eta: 0:55:12  iter: 1099  total_loss: 0.3693  loss_cls: 0.07668  loss_box_reg: 0.08536  loss_mask: 0.1582  loss_rpn_cls: 0.004544  loss_rpn_loc: 0.007737     lr: 0.00025  max_mem: 1772M
# [04/27 05:47:09 d2.utils.events]:  eta: 0:54:40  iter: 1119  total_loss: 0.2625  loss_cls: 0.05624  loss_box_reg: 0.0591  loss_mask: 0.1216  loss_rpn_cls: 0.002166  loss_rpn_loc: 0.00916     lr: 0.00025  max_mem: 1772M
# [04/27 05:47:16 d2.utils.events]:  eta: 0:54:14  iter: 1139  total_loss: 0.2815  loss_cls: 0.06469  loss_box_reg: 0.05866  loss_mask: 0.136  loss_rpn_cls: 0.003631  loss_rpn_loc: 0.008252     lr: 0.00025  max_mem: 1772M
# [04/27 05:47:24 d2.utils.events]:  eta: 0:56:12  iter: 1159  total_loss: 0.2727  loss_cls: 0.06186  loss_box_reg: 0.07384  loss_mask: 0.1235  loss_rpn_cls: 0.001199  loss_rpn_loc: 0.008425     lr: 0.00025  max_mem: 1772M
# [04/27 05:47:31 d2.utils.events]:  eta: 0:52:32  iter: 1179  total_loss: 0.2748  loss_cls: 0.06229  loss_box_reg: 0.06563  loss_mask: 0.1198  loss_rpn_cls: 0.0002819  loss_rpn_loc: 0.009409     lr: 0.00025  max_mem: 1772M
# [04/27 05:47:39 d2.utils.events]:  eta: 0:56:10  iter: 1199  total_loss: 0.2861  loss_cls: 0.06413  loss_box_reg: 0.06157  loss_mask: 0.1447  loss_rpn_cls: 0.004616  loss_rpn_loc: 0.01049     lr: 0.00025  max_mem: 1772M
# Loss has not improved for 100 iterations
# [04/27 05:47:46 d2.utils.events]:  eta: 0:55:06  iter: 1219  total_loss: 0.2565  loss_cls: 0.05703  loss_box_reg: 0.05557  loss_mask: 0.1389  loss_rpn_cls: 0.0005433  loss_rpn_loc: 0.00892     lr: 0.00025  max_mem: 1772M
# [04/27 05:47:54 d2.utils.events]:  eta: 0:55:40  iter: 1239  total_loss: 0.2796  loss_cls: 0.06608  loss_box_reg: 0.06848  loss_mask: 0.1397  loss_rpn_cls: 0.0004943  loss_rpn_loc: 0.008477     lr: 0.00025  max_mem: 1772M
# [04/27 05:48:02 d2.utils.events]:  eta: 0:54:59  iter: 1259  total_loss: 0.2889  loss_cls: 0.06526  loss_box_reg: 0.07248  loss_mask: 0.1437  loss_rpn_cls: 0.001192  loss_rpn_loc: 0.00955     lr: 0.00025  max_mem: 1772M
# [04/27 05:48:09 d2.utils.events]:  eta: 0:56:02  iter: 1279  total_loss: 0.2443  loss_cls: 0.06795  loss_box_reg: 0.0671  loss_mask: 0.1274  loss_rpn_cls: 0.002656  loss_rpn_loc: 0.007895     lr: 0.00025  max_mem: 1772M
# [04/27 05:48:17 d2.utils.events]:  eta: 0:53:38  iter: 1299  total_loss: 0.2308  loss_cls: 0.06253  loss_box_reg: 0.05709  loss_mask: 0.1163  loss_rpn_cls: 0.0003674  loss_rpn_loc: 0.006271     lr: 0.00025  max_mem: 1772M
# Loss has not improved for 200 iterations
# [04/27 05:48:25 d2.utils.events]:  eta: 0:56:42  iter: 1319  total_loss: 0.2847  loss_cls: 0.0698  loss_box_reg: 0.06799  loss_mask: 0.137  loss_rpn_cls: 0.001141  loss_rpn_loc: 0.008361     lr: 0.00025  max_mem: 1772M
# [04/27 05:48:32 d2.utils.events]:  eta: 0:51:57  iter: 1339  total_loss: 0.2488  loss_cls: 0.04841  loss_box_reg: 0.04879  loss_mask: 0.1177  loss_rpn_cls: 0.0007204  loss_rpn_loc: 0.00945     lr: 0.00025  max_mem: 1772M
# [04/27 05:48:39 d2.utils.events]:  eta: 0:52:44  iter: 1359  total_loss: 0.2653  loss_cls: 0.0488  loss_box_reg: 0.05698  loss_mask: 0.1332  loss_rpn_cls: 0.0007155  loss_rpn_loc: 0.00763     lr: 0.00025  max_mem: 1772M
# [04/27 05:48:46 d2.utils.events]:  eta: 0:52:40  iter: 1379  total_loss: 0.2483  loss_cls: 0.05349  loss_box_reg: 0.05596  loss_mask: 0.1181  loss_rpn_cls: 0.0009577  loss_rpn_loc: 0.00641     lr: 0.00025  max_mem: 1772M
# [04/27 05:48:54 d2.utils.events]:  eta: 0:55:13  iter: 1399  total_loss: 0.2647  loss_cls: 0.06535  loss_box_reg: 0.06676  loss_mask: 0.1324  loss_rpn_cls: 0.0007919  loss_rpn_loc: 0.008857     lr: 0.00025  max_mem: 1772M
# [04/27 05:49:02 d2.utils.events]:  eta: 0:54:23  iter: 1419  total_loss: 0.2465  loss_cls: 0.05038  loss_box_reg: 0.05067  loss_mask: 0.1313  loss_rpn_cls: 0.001044  loss_rpn_loc: 0.008654     lr: 0.00025  max_mem: 1786M
# [04/27 05:49:09 d2.utils.events]:  eta: 0:54:48  iter: 1439  total_loss: 0.2199  loss_cls: 0.04013  loss_box_reg: 0.0462  loss_mask: 0.1081  loss_rpn_cls: 0.000186  loss_rpn_loc: 0.005651     lr: 0.00025  max_mem: 1786M
# [04/27 05:49:17 d2.utils.events]:  eta: 0:53:21  iter: 1459  total_loss: 0.235  loss_cls: 0.05195  loss_box_reg: 0.05079  loss_mask: 0.1264  loss_rpn_cls: 0.0002298  loss_rpn_loc: 0.008287     lr: 0.00025  max_mem: 1786M
# [04/27 05:49:24 d2.utils.events]:  eta: 0:53:00  iter: 1479  total_loss: 0.3145  loss_cls: 0.06572  loss_box_reg: 0.07765  loss_mask: 0.1363  loss_rpn_cls: 0.001225  loss_rpn_loc: 0.007785     lr: 0.00025  max_mem: 1786M
# [04/27 05:49:32 d2.utils.events]:  eta: 0:55:41  iter: 1499  total_loss: 0.2585  loss_cls: 0.07928  loss_box_reg: 0.06475  loss_mask: 0.1159  loss_rpn_cls: 0.0008757  loss_rpn_loc: 0.007092     lr: 0.00025  max_mem: 1786M
# [04/27 05:49:40 d2.utils.events]:  eta: 0:53:09  iter: 1519  total_loss: 0.2422  loss_cls: 0.04934  loss_box_reg: 0.05856  loss_mask: 0.1226  loss_rpn_cls: 0.0009424  loss_rpn_loc: 0.01147     lr: 0.00025  max_mem: 1786M
# [04/27 05:49:47 d2.utils.events]:  eta: 0:53:52  iter: 1539  total_loss: 0.2276  loss_cls: 0.05065  loss_box_reg: 0.04768  loss_mask: 0.1253  loss_rpn_cls: 0.000951  loss_rpn_loc: 0.008298     lr: 0.00025  max_mem: 1786M
# [04/27 05:49:55 d2.utils.events]:  eta: 0:52:39  iter: 1559  total_loss: 0.2762  loss_cls: 0.06393  loss_box_reg: 0.06839  loss_mask: 0.1608  loss_rpn_cls: 0.0009909  loss_rpn_loc: 0.007271     lr: 0.00025  max_mem: 1786M
# [04/27 05:50:02 d2.utils.events]:  eta: 0:52:05  iter: 1579  total_loss: 0.207  loss_cls: 0.03834  loss_box_reg: 0.0443  loss_mask: 0.1183  loss_rpn_cls: 0.000339  loss_rpn_loc: 0.007628     lr: 0.00025  max_mem: 1786M
# [04/27 05:50:10 d2.utils.events]:  eta: 0:54:46  iter: 1599  total_loss: 0.2076  loss_cls: 0.03989  loss_box_reg: 0.04849  loss_mask: 0.09902  loss_rpn_cls: 0.0007537  loss_rpn_loc: 0.007539     lr: 0.00025  max_mem: 1786M
# [04/27 05:50:18 d2.utils.events]:  eta: 0:52:31  iter: 1619  total_loss: 0.219  loss_cls: 0.04938  loss_box_reg: 0.04544  loss_mask: 0.1132  loss_rpn_cls: 0.003134  loss_rpn_loc: 0.00793     lr: 0.00025  max_mem: 1786M
# Loss has not improved for 100 iterations
# [04/27 05:50:25 d2.utils.events]:  eta: 0:53:25  iter: 1639  total_loss: 0.1963  loss_cls: 0.03855  loss_box_reg: 0.04178  loss_mask: 0.119  loss_rpn_cls: 0.0004574  loss_rpn_loc: 0.007213     lr: 0.00025  max_mem: 1786M
# [04/27 05:50:33 d2.utils.events]:  eta: 0:50:47  iter: 1659  total_loss: 0.2381  loss_cls: 0.04972  loss_box_reg: 0.0514  loss_mask: 0.1184  loss_rpn_cls: 0.0008028  loss_rpn_loc: 0.006459     lr: 0.00025  max_mem: 1786M
# [04/27 05:50:40 d2.utils.events]:  eta: 0:48:50  iter: 1679  total_loss: 0.194  loss_cls: 0.04234  loss_box_reg: 0.04617  loss_mask: 0.09983  loss_rpn_cls: 0.0008971  loss_rpn_loc: 0.008677     lr: 0.00025  max_mem: 1786M
# [04/27 05:50:47 d2.utils.events]:  eta: 0:52:30  iter: 1699  total_loss: 0.2179  loss_cls: 0.04072  loss_box_reg: 0.04286  loss_mask: 0.1323  loss_rpn_cls: 0.0002813  loss_rpn_loc: 0.007666     lr: 0.00025  max_mem: 1786M
# [04/27 05:50:55 d2.utils.events]:  eta: 0:52:16  iter: 1719  total_loss: 0.2092  loss_cls: 0.04352  loss_box_reg: 0.05002  loss_mask: 0.11  loss_rpn_cls: 0.0003527  loss_rpn_loc: 0.006144     lr: 0.00025  max_mem: 1786M
# [04/27 05:51:02 d2.utils.events]:  eta: 0:51:14  iter: 1739  total_loss: 0.1912  loss_cls: 0.04039  loss_box_reg: 0.0484  loss_mask: 0.1054  loss_rpn_cls: 0.0009758  loss_rpn_loc: 0.008587     lr: 0.00025  max_mem: 1786M
# [04/27 05:51:10 d2.utils.events]:  eta: 0:50:57  iter: 1759  total_loss: 0.2149  loss_cls: 0.03379  loss_box_reg: 0.04363  loss_mask: 0.1184  loss_rpn_cls: 0.0007064  loss_rpn_loc: 0.006207     lr: 0.00025  max_mem: 1786M
# [04/27 05:51:17 d2.utils.events]:  eta: 0:53:02  iter: 1779  total_loss: 0.276  loss_cls: 0.04856  loss_box_reg: 0.06212  loss_mask: 0.1447  loss_rpn_cls: 0.002273  loss_rpn_loc: 0.007932     lr: 0.00025  max_mem: 1786M
# Loss has not improved for 100 iterations
# [04/27 05:51:25 d2.utils.events]:  eta: 0:52:13  iter: 1799  total_loss: 0.2305  loss_cls: 0.04396  loss_box_reg: 0.05134  loss_mask: 0.118  loss_rpn_cls: 0.0003944  loss_rpn_loc: 0.006866     lr: 0.00025  max_mem: 1786M
# [04/27 05:51:33 d2.utils.events]:  eta: 0:51:23  iter: 1819  total_loss: 0.1949  loss_cls: 0.03478  loss_box_reg: 0.04471  loss_mask: 0.1226  loss_rpn_cls: 0.0006668  loss_rpn_loc: 0.0076     lr: 0.00025  max_mem: 1786M
# [04/27 05:51:40 d2.utils.events]:  eta: 0:52:56  iter: 1839  total_loss: 0.2207  loss_cls: 0.0502  loss_box_reg: 0.05206  loss_mask: 0.1184  loss_rpn_cls: 0.0008187  loss_rpn_loc: 0.008371     lr: 0.00025  max_mem: 1786M
# [04/27 05:51:48 d2.utils.events]:  eta: 0:52:07  iter: 1859  total_loss: 0.2217  loss_cls: 0.04425  loss_box_reg: 0.04729  loss_mask: 0.108  loss_rpn_cls: 0.0003804  loss_rpn_loc: 0.006515     lr: 0.00025  max_mem: 1786M
# [04/27 05:51:56 d2.utils.events]:  eta: 0:52:00  iter: 1879  total_loss: 0.2563  loss_cls: 0.04694  loss_box_reg: 0.07594  loss_mask: 0.1137  loss_rpn_cls: 0.0003315  loss_rpn_loc: 0.007617     lr: 0.00025  max_mem: 1786M
# [04/27 05:52:04 d2.utils.events]:  eta: 0:52:15  iter: 1899  total_loss: 0.1965  loss_cls: 0.0342  loss_box_reg: 0.04619  loss_mask: 0.1053  loss_rpn_cls: 0.0006518  loss_rpn_loc: 0.00573     lr: 0.00025  max_mem: 1786M
# [04/27 05:52:11 d2.utils.events]:  eta: 0:49:23  iter: 1919  total_loss: 0.1876  loss_cls: 0.04382  loss_box_reg: 0.03851  loss_mask: 0.1022  loss_rpn_cls: 0.0006152  loss_rpn_loc: 0.004997     lr: 0.00025  max_mem: 1786M
# [04/27 05:52:18 d2.utils.events]:  eta: 0:48:25  iter: 1939  total_loss: 0.1894  loss_cls: 0.02954  loss_box_reg: 0.03436  loss_mask: 0.1123  loss_rpn_cls: 0.0006404  loss_rpn_loc: 0.00774     lr: 0.00025  max_mem: 1786M
# [04/27 05:52:26 d2.utils.events]:  eta: 0:51:17  iter: 1959  total_loss: 0.204  loss_cls: 0.0506  loss_box_reg: 0.05536  loss_mask: 0.102  loss_rpn_cls: 0.0005103  loss_rpn_loc: 0.007159     lr: 0.00025  max_mem: 1786M
# [04/27 05:52:33 d2.utils.events]:  eta: 0:49:39  iter: 1979  total_loss: 0.235  loss_cls: 0.03706  loss_box_reg: 0.05404  loss_mask: 0.1316  loss_rpn_cls: 0.0004566  loss_rpn_loc: 0.009763     lr: 0.00025  max_mem: 1786M
# Loss has not improved for 100 iterations
# [04/27 05:52:41 d2.utils.events]:  eta: 0:51:33  iter: 1999  total_loss: 0.2083  loss_cls: 0.03533  loss_box_reg: 0.05263  loss_mask: 0.1132  loss_rpn_cls: 0.0002629  loss_rpn_loc: 0.007033     lr: 0.00025  max_mem: 1786M
# [04/27 05:52:49 d2.utils.events]:  eta: 0:50:43  iter: 2019  total_loss: 0.2047  loss_cls: 0.03905  loss_box_reg: 0.05066  loss_mask: 0.1155  loss_rpn_cls: 0.0002407  loss_rpn_loc: 0.00685     lr: 0.00025  max_mem: 1786M
# [04/27 05:52:56 d2.utils.events]:  eta: 0:49:36  iter: 2039  total_loss: 0.1978  loss_cls: 0.04096  loss_box_reg: 0.04497  loss_mask: 0.1144  loss_rpn_cls: 0.0007141  loss_rpn_loc: 0.007051     lr: 0.00025  max_mem: 1786M
# [04/27 05:53:04 d2.utils.events]:  eta: 0:50:29  iter: 2059  total_loss: 0.2082  loss_cls: 0.03325  loss_box_reg: 0.03824  loss_mask: 0.09256  loss_rpn_cls: 0.0001989  loss_rpn_loc: 0.007449     lr: 0.00025  max_mem: 1786M
# [04/27 05:53:11 d2.utils.events]:  eta: 0:50:03  iter: 2079  total_loss: 0.1839  loss_cls: 0.03531  loss_box_reg: 0.04616  loss_mask: 0.09388  loss_rpn_cls: 0.0003174  loss_rpn_loc: 0.005638     lr: 0.00025  max_mem: 1786M
# [04/27 05:53:19 d2.utils.events]:  eta: 0:49:52  iter: 2099  total_loss: 0.1964  loss_cls: 0.03941  loss_box_reg: 0.04274  loss_mask: 0.1102  loss_rpn_cls: 0.0001773  loss_rpn_loc: 0.007046     lr: 0.00025  max_mem: 1786M
# [04/27 05:53:27 d2.utils.events]:  eta: 0:52:04  iter: 2119  total_loss: 0.216  loss_cls: 0.04693  loss_box_reg: 0.06103  loss_mask: 0.1053  loss_rpn_cls: 0.0007444  loss_rpn_loc: 0.006013     lr: 0.00025  max_mem: 1786M
# [04/27 05:53:34 d2.utils.events]:  eta: 0:49:31  iter: 2139  total_loss: 0.2214  loss_cls: 0.04035  loss_box_reg: 0.04206  loss_mask: 0.1123  loss_rpn_cls: 0.000174  loss_rpn_loc: 0.005455     lr: 0.00025  max_mem: 1786M
# Loss has not improved for 100 iterations
# [04/27 05:53:42 d2.utils.events]:  eta: 0:50:10  iter: 2159  total_loss: 0.1863  loss_cls: 0.03427  loss_box_reg: 0.03395  loss_mask: 0.09792  loss_rpn_cls: 0.0006889  loss_rpn_loc: 0.006555     lr: 0.00025  max_mem: 1786M
# [04/27 05:53:50 d2.utils.events]:  eta: 0:50:09  iter: 2179  total_loss: 0.1801  loss_cls: 0.03189  loss_box_reg: 0.04666  loss_mask: 0.09277  loss_rpn_cls: 0.0004811  loss_rpn_loc: 0.006076     lr: 0.00025  max_mem: 1786M
# [04/27 05:53:57 d2.utils.events]:  eta: 0:48:43  iter: 2199  total_loss: 0.1812  loss_cls: 0.03086  loss_box_reg: 0.03924  loss_mask: 0.1168  loss_rpn_cls: 0.0007088  loss_rpn_loc: 0.006798     lr: 0.00025  max_mem: 1786M
# [04/27 05:54:05 d2.utils.events]:  eta: 0:48:08  iter: 2219  total_loss: 0.2028  loss_cls: 0.03564  loss_box_reg: 0.04832  loss_mask: 0.1137  loss_rpn_cls: 0.0004607  loss_rpn_loc: 0.00718     lr: 0.00025  max_mem: 1786M
# [04/27 05:54:12 d2.utils.events]:  eta: 0:48:35  iter: 2239  total_loss: 0.1941  loss_cls: 0.03904  loss_box_reg: 0.05798  loss_mask: 0.09339  loss_rpn_cls: 0.0006238  loss_rpn_loc: 0.004578     lr: 0.00025  max_mem: 1786M
# Loss has not improved for 100 iterations
# [04/27 05:54:20 d2.utils.events]:  eta: 0:48:48  iter: 2259  total_loss: 0.1971  loss_cls: 0.03727  loss_box_reg: 0.04087  loss_mask: 0.1066  loss_rpn_cls: 0.0006298  loss_rpn_loc: 0.007187     lr: 0.00025  max_mem: 1805M
# [04/27 05:54:27 d2.utils.events]:  eta: 0:48:24  iter: 2279  total_loss: 0.199  loss_cls: 0.03618  loss_box_reg: 0.04416  loss_mask: 0.104  loss_rpn_cls: 0.0005469  loss_rpn_loc: 0.006116     lr: 0.00025  max_mem: 1805M
# [04/27 05:54:35 d2.utils.events]:  eta: 0:49:20  iter: 2299  total_loss: 0.2373  loss_cls: 0.04359  loss_box_reg: 0.04478  loss_mask: 0.1328  loss_rpn_cls: 0.0002104  loss_rpn_loc: 0.007359     lr: 0.00025  max_mem: 1805M
# [04/27 05:54:42 d2.utils.events]:  eta: 0:48:32  iter: 2319  total_loss: 0.1888  loss_cls: 0.03694  loss_box_reg: 0.04441  loss_mask: 0.1056  loss_rpn_cls: 0.001159  loss_rpn_loc: 0.006487     lr: 0.00025  max_mem: 1805M
# [04/27 05:54:50 d2.utils.events]:  eta: 0:48:39  iter: 2339  total_loss: 0.1909  loss_cls: 0.0366  loss_box_reg: 0.04735  loss_mask: 0.1043  loss_rpn_cls: 0.000522  loss_rpn_loc: 0.004254     lr: 0.00025  max_mem: 1805M
# Loss has not improved for 200 iterations
# [04/27 05:54:58 d2.utils.events]:  eta: 0:48:17  iter: 2359  total_loss: 0.2442  loss_cls: 0.03473  loss_box_reg: 0.0448  loss_mask: 0.1088  loss_rpn_cls: 0.0002808  loss_rpn_loc: 0.005924     lr: 0.00025  max_mem: 1805M
# [04/27 05:55:05 d2.utils.events]:  eta: 0:48:20  iter: 2379  total_loss: 0.1461  loss_cls: 0.02618  loss_box_reg: 0.03458  loss_mask: 0.07982  loss_rpn_cls: 8.973e-05  loss_rpn_loc: 0.005701     lr: 0.00025  max_mem: 1805M
# [04/27 05:55:13 d2.utils.events]:  eta: 0:47:19  iter: 2399  total_loss: 0.2145  loss_cls: 0.03308  loss_box_reg: 0.03973  loss_mask: 0.1264  loss_rpn_cls: 0.0005059  loss_rpn_loc: 0.009545     lr: 0.00025  max_mem: 1805M
# [04/27 05:55:20 d2.utils.events]:  eta: 0:47:33  iter: 2419  total_loss: 0.2116  loss_cls: 0.03993  loss_box_reg: 0.05865  loss_mask: 0.1057  loss_rpn_cls: 0.0007646  loss_rpn_loc: 0.006221     lr: 0.00025  max_mem: 1805M
# [04/27 05:55:28 d2.utils.events]:  eta: 0:46:00  iter: 2439  total_loss: 0.178  loss_cls: 0.02984  loss_box_reg: 0.03622  loss_mask: 0.1094  loss_rpn_cls: 0.0002532  loss_rpn_loc: 0.005715     lr: 0.00025  max_mem: 1805M
# Loss has not improved for 300 iterations
# [04/27 05:55:36 d2.utils.events]:  eta: 0:50:27  iter: 2459  total_loss: 0.3211  loss_cls: 0.06206  loss_box_reg: 0.09042  loss_mask: 0.1529  loss_rpn_cls: 0.0004965  loss_rpn_loc: 0.008024     lr: 0.00025  max_mem: 1805M
# [04/27 05:55:43 d2.utils.events]:  eta: 0:47:26  iter: 2479  total_loss: 0.1664  loss_cls: 0.0312  loss_box_reg: 0.03499  loss_mask: 0.08748  loss_rpn_cls: 0.0003257  loss_rpn_loc: 0.007033     lr: 0.00025  max_mem: 1805M
# [04/27 05:55:51 d2.utils.events]:  eta: 0:46:34  iter: 2499  total_loss: 0.19  loss_cls: 0.02977  loss_box_reg: 0.03604  loss_mask: 0.09857  loss_rpn_cls: 0.0001394  loss_rpn_loc: 0.005688     lr: 0.00025  max_mem: 1805M
# [04/27 05:55:58 d2.utils.events]:  eta: 0:47:23  iter: 2519  total_loss: 0.1542  loss_cls: 0.03062  loss_box_reg: 0.03382  loss_mask: 0.08618  loss_rpn_cls: 0.0003033  loss_rpn_loc: 0.006914     lr: 0.00025  max_mem: 1805M
# [04/27 05:56:06 d2.utils.events]:  eta: 0:48:25  iter: 2539  total_loss: 0.1662  loss_cls: 0.03112  loss_box_reg: 0.03973  loss_mask: 0.08945  loss_rpn_cls: 0.0001471  loss_rpn_loc: 0.005237     lr: 0.00025  max_mem: 1805M
# [04/27 05:56:14 d2.utils.events]:  eta: 0:49:23  iter: 2559  total_loss: 0.2031  loss_cls: 0.03162  loss_box_reg: 0.04405  loss_mask: 0.1075  loss_rpn_cls: 0.0006446  loss_rpn_loc: 0.006493     lr: 0.00025  max_mem: 1805M
# [04/27 05:56:22 d2.utils.events]:  eta: 0:46:53  iter: 2579  total_loss: 0.2425  loss_cls: 0.03466  loss_box_reg: 0.06251  loss_mask: 0.1315  loss_rpn_cls: 0.0004865  loss_rpn_loc: 0.006618     lr: 0.00025  max_mem: 1805M
# [04/27 05:56:29 d2.utils.events]:  eta: 0:46:30  iter: 2599  total_loss: 0.1852  loss_cls: 0.03108  loss_box_reg: 0.04171  loss_mask: 0.1038  loss_rpn_cls: 6.24e-05  loss_rpn_loc: 0.007673     lr: 0.00025  max_mem: 1805M
# Loss has not improved for 100 iterations
# [04/27 05:56:37 d2.utils.events]:  eta: 0:46:37  iter: 2619  total_loss: 0.1677  loss_cls: 0.02682  loss_box_reg: 0.03629  loss_mask: 0.09295  loss_rpn_cls: 0.0002687  loss_rpn_loc: 0.006964     lr: 0.00025  max_mem: 1805M
# [04/27 05:56:44 d2.utils.events]:  eta: 0:47:20  iter: 2639  total_loss: 0.1826  loss_cls: 0.03027  loss_box_reg: 0.04359  loss_mask: 0.1026  loss_rpn_cls: 0.0002301  loss_rpn_loc: 0.007651     lr: 0.00025  max_mem: 1805M
# [04/27 05:56:52 d2.utils.events]:  eta: 0:47:39  iter: 2659  total_loss: 0.1552  loss_cls: 0.02867  loss_box_reg: 0.04089  loss_mask: 0.07537  loss_rpn_cls: 0.000159  loss_rpn_loc: 0.004787     lr: 0.00025  max_mem: 1805M
# [04/27 05:57:00 d2.utils.events]:  eta: 0:45:39  iter: 2679  total_loss: 0.1608  loss_cls: 0.0255  loss_box_reg: 0.03283  loss_mask: 0.09697  loss_rpn_cls: 0.0001401  loss_rpn_loc: 0.006953     lr: 0.00025  max_mem: 1805M
# [04/27 05:57:07 d2.utils.events]:  eta: 0:47:02  iter: 2699  total_loss: 0.1809  loss_cls: 0.03166  loss_box_reg: 0.03503  loss_mask: 0.1005  loss_rpn_cls: 0.0002699  loss_rpn_loc: 0.006859     lr: 0.00025  max_mem: 1805M
# Loss has not improved for 200 iterations
# [04/27 05:57:15 d2.utils.events]:  eta: 0:46:25  iter: 2719  total_loss: 0.1926  loss_cls: 0.03423  loss_box_reg: 0.03868  loss_mask: 0.1011  loss_rpn_cls: 0.000749  loss_rpn_loc: 0.006998     lr: 0.00025  max_mem: 1805M
# [04/27 05:57:23 d2.utils.events]:  eta: 0:45:35  iter: 2739  total_loss: 0.2207  loss_cls: 0.04299  loss_box_reg: 0.05351  loss_mask: 0.1095  loss_rpn_cls: 0.001191  loss_rpn_loc: 0.006633     lr: 0.00025  max_mem: 1805M
# [04/27 05:57:30 d2.utils.events]:  eta: 0:45:51  iter: 2759  total_loss: 0.1375  loss_cls: 0.02225  loss_box_reg: 0.03146  loss_mask: 0.07665  loss_rpn_cls: 0.000356  loss_rpn_loc: 0.005934     lr: 0.00025  max_mem: 1805M
# [04/27 05:57:38 d2.utils.events]:  eta: 0:46:38  iter: 2779  total_loss: 0.1764  loss_cls: 0.03365  loss_box_reg: 0.04672  loss_mask: 0.09311  loss_rpn_cls: 0.0003921  loss_rpn_loc: 0.005116     lr: 0.00025  max_mem: 1805M
# [04/27 05:57:46 d2.utils.events]:  eta: 0:46:14  iter: 2799  total_loss: 0.1868  loss_cls: 0.02842  loss_box_reg: 0.04645  loss_mask: 0.09602  loss_rpn_cls: 0.0001764  loss_rpn_loc: 0.006045     lr: 0.00025  max_mem: 1805M
# Loss has not improved for 300 iterations
# [04/27 05:57:53 d2.utils.events]:  eta: 0:44:41  iter: 2819  total_loss: 0.1972  loss_cls: 0.02635  loss_box_reg: 0.04505  loss_mask: 0.111  loss_rpn_cls: 0.0004181  loss_rpn_loc: 0.007861     lr: 0.00025  max_mem: 1805M
# [04/27 05:58:01 d2.utils.events]:  eta: 0:44:45  iter: 2839  total_loss: 0.1921  loss_cls: 0.02595  loss_box_reg: 0.03815  loss_mask: 0.1073  loss_rpn_cls: 0.0003629  loss_rpn_loc: 0.008132     lr: 0.00025  max_mem: 1805M
# [04/27 05:58:08 d2.utils.events]:  eta: 0:43:56  iter: 2859  total_loss: 0.157  loss_cls: 0.02832  loss_box_reg: 0.0338  loss_mask: 0.08932  loss_rpn_cls: 0.0006167  loss_rpn_loc: 0.00481     lr: 0.00025  max_mem: 1805M
# [04/27 05:58:16 d2.utils.events]:  eta: 0:46:07  iter: 2879  total_loss: 0.1422  loss_cls: 0.02398  loss_box_reg: 0.03317  loss_mask: 0.0764  loss_rpn_cls: 7.946e-05  loss_rpn_loc: 0.005612     lr: 0.00025  max_mem: 1805M
# [04/27 05:58:24 d2.utils.events]:  eta: 0:46:23  iter: 2899  total_loss: 0.183  loss_cls: 0.02667  loss_box_reg: 0.04742  loss_mask: 0.1014  loss_rpn_cls: 0.0004226  loss_rpn_loc: 0.007655     lr: 0.00025  max_mem: 1805M
# [04/27 05:58:31 d2.utils.events]:  eta: 0:45:58  iter: 2919  total_loss: 0.2156  loss_cls: 0.03173  loss_box_reg: 0.04952  loss_mask: 0.1067  loss_rpn_cls: 0.0002563  loss_rpn_loc: 0.00563     lr: 0.00025  max_mem: 1805M
# [04/27 05:58:39 d2.utils.events]:  eta: 0:44:55  iter: 2939  total_loss: 0.168  loss_cls: 0.02863  loss_box_reg: 0.0336  loss_mask: 0.09545  loss_rpn_cls: 7.305e-05  loss_rpn_loc: 0.004771     lr: 0.00025  max_mem: 1805M
# [04/27 05:58:47 d2.utils.events]:  eta: 0:44:24  iter: 2959  total_loss: 0.1721  loss_cls: 0.02686  loss_box_reg: 0.03725  loss_mask: 0.09799  loss_rpn_cls: 0.0001112  loss_rpn_loc: 0.005682     lr: 0.00025  max_mem: 1805M
# Loss has not improved for 100 iterations
# [04/27 05:58:54 d2.utils.events]:  eta: 0:44:49  iter: 2979  total_loss: 0.1643  loss_cls: 0.02538  loss_box_reg: 0.03702  loss_mask: 0.08494  loss_rpn_cls: 0.0001028  loss_rpn_loc: 0.006669     lr: 0.00025  max_mem: 1805M
# [04/27 05:59:02 d2.utils.events]:  eta: 0:44:11  iter: 2999  total_loss: 0.1447  loss_cls: 0.02159  loss_box_reg: 0.03078  loss_mask: 0.0908  loss_rpn_cls: 0.00023  loss_rpn_loc: 0.005569     lr: 0.00025  max_mem: 1805M
# [04/27 05:59:09 d2.utils.events]:  eta: 0:43:42  iter: 3019  total_loss: 0.1552  loss_cls: 0.02535  loss_box_reg: 0.03671  loss_mask: 0.08268  loss_rpn_cls: 0.0003834  loss_rpn_loc: 0.006845     lr: 0.00025  max_mem: 1805M
# [04/27 05:59:17 d2.utils.events]:  eta: 0:45:53  iter: 3039  total_loss: 0.1499  loss_cls: 0.02357  loss_box_reg: 0.03839  loss_mask: 0.0833  loss_rpn_cls: 0.0001557  loss_rpn_loc: 0.005971     lr: 0.00025  max_mem: 1805M
# [04/27 05:59:25 d2.utils.events]:  eta: 0:45:09  iter: 3059  total_loss: 0.1646  loss_cls: 0.02639  loss_box_reg: 0.04731  loss_mask: 0.08731  loss_rpn_cls: 0.0005616  loss_rpn_loc: 0.00713     lr: 0.00025  max_mem: 1805M
# Loss has not improved for 200 iterations
# [04/27 05:59:33 d2.utils.events]:  eta: 0:44:38  iter: 3079  total_loss: 0.2214  loss_cls: 0.03254  loss_box_reg: 0.05839  loss_mask: 0.1141  loss_rpn_cls: 0.0005638  loss_rpn_loc: 0.006309     lr: 0.00025  max_mem: 1805M
# [04/27 05:59:40 d2.utils.events]:  eta: 0:41:59  iter: 3099  total_loss: 0.1581  loss_cls: 0.02746  loss_box_reg: 0.03864  loss_mask: 0.09173  loss_rpn_cls: 7.26e-05  loss_rpn_loc: 0.006439     lr: 0.00025  max_mem: 1805M
# [04/27 05:59:48 d2.utils.events]:  eta: 0:42:12  iter: 3119  total_loss: 0.1682  loss_cls: 0.02434  loss_box_reg: 0.03727  loss_mask: 0.1004  loss_rpn_cls: 5.439e-05  loss_rpn_loc: 0.00567     lr: 0.00025  max_mem: 1805M
# [04/27 05:59:55 d2.utils.events]:  eta: 0:44:18  iter: 3139  total_loss: 0.1812  loss_cls: 0.03106  loss_box_reg: 0.0444  loss_mask: 0.1015  loss_rpn_cls: 0.0004773  loss_rpn_loc: 0.007292     lr: 0.00025  max_mem: 1805M
# [04/27 06:00:03 d2.utils.events]:  eta: 0:42:55  iter: 3159  total_loss: 0.1517  loss_cls: 0.02288  loss_box_reg: 0.03237  loss_mask: 0.08132  loss_rpn_cls: 0.0003131  loss_rpn_loc: 0.005994     lr: 0.00025  max_mem: 1805M
# [04/27 06:00:11 d2.utils.events]:  eta: 0:44:04  iter: 3179  total_loss: 0.1833  loss_cls: 0.02679  loss_box_reg: 0.0349  loss_mask: 0.1085  loss_rpn_cls: 9.719e-05  loss_rpn_loc: 0.006919     lr: 0.00025  max_mem: 1805M
# Loss has not improved for 100 iterations
# [04/27 06:00:18 d2.utils.events]:  eta: 0:41:39  iter: 3199  total_loss: 0.1524  loss_cls: 0.02154  loss_box_reg: 0.03159  loss_mask: 0.08529  loss_rpn_cls: 0.0002522  loss_rpn_loc: 0.007022     lr: 0.00025  max_mem: 1805M
# [04/27 06:00:26 d2.utils.events]:  eta: 0:43:13  iter: 3219  total_loss: 0.1954  loss_cls: 0.03283  loss_box_reg: 0.04478  loss_mask: 0.09907  loss_rpn_cls: 0.0003291  loss_rpn_loc: 0.006973     lr: 0.00025  max_mem: 1805M
# [04/27 06:00:33 d2.utils.events]:  eta: 0:43:17  iter: 3239  total_loss: 0.1477  loss_cls: 0.02801  loss_box_reg: 0.03213  loss_mask: 0.08603  loss_rpn_cls: 0.0003903  loss_rpn_loc: 0.007339     lr: 0.00025  max_mem: 1805M
# [04/27 06:00:41 d2.utils.events]:  eta: 0:42:06  iter: 3259  total_loss: 0.134  loss_cls: 0.02126  loss_box_reg: 0.03101  loss_mask: 0.07847  loss_rpn_cls: 0.0001152  loss_rpn_loc: 0.004541     lr: 0.00025  max_mem: 1805M
# [04/27 06:00:49 d2.utils.events]:  eta: 0:44:59  iter: 3279  total_loss: 0.1835  loss_cls: 0.02627  loss_box_reg: 0.04422  loss_mask: 0.08709  loss_rpn_cls: 0.0001969  loss_rpn_loc: 0.004796     lr: 0.00025  max_mem: 1805M
# Loss has not improved for 200 iterations
# [04/27 06:00:56 d2.utils.events]:  eta: 0:43:03  iter: 3299  total_loss: 0.1648  loss_cls: 0.02572  loss_box_reg: 0.03522  loss_mask: 0.1054  loss_rpn_cls: 0.0001658  loss_rpn_loc: 0.005912     lr: 0.00025  max_mem: 1805M
# [04/27 06:01:04 d2.utils.events]:  eta: 0:44:10  iter: 3319  total_loss: 0.159  loss_cls: 0.02713  loss_box_reg: 0.03394  loss_mask: 0.08921  loss_rpn_cls: 0.00045  loss_rpn_loc: 0.006112     lr: 0.00025  max_mem: 1805M
# [04/27 06:01:12 d2.utils.events]:  eta: 0:43:06  iter: 3339  total_loss: 0.17  loss_cls: 0.02628  loss_box_reg: 0.041  loss_mask: 0.09521  loss_rpn_cls: 0.0001217  loss_rpn_loc: 0.00439     lr: 0.00025  max_mem: 1805M
# [04/27 06:01:20 d2.utils.events]:  eta: 0:42:13  iter: 3359  total_loss: 0.1638  loss_cls: 0.02447  loss_box_reg: 0.02993  loss_mask: 0.08556  loss_rpn_cls: 0.0003366  loss_rpn_loc: 0.008279     lr: 0.00025  max_mem: 1805M
# [04/27 06:01:28 d2.utils.events]:  eta: 0:43:03  iter: 3379  total_loss: 0.1289  loss_cls: 0.02303  loss_box_reg: 0.02596  loss_mask: 0.08254  loss_rpn_cls: 0.0001198  loss_rpn_loc: 0.006398     lr: 0.00025  max_mem: 1805M
# [04/27 06:01:35 d2.utils.events]:  eta: 0:41:21  iter: 3399  total_loss: 0.1557  loss_cls: 0.02947  loss_box_reg: 0.046  loss_mask: 0.08424  loss_rpn_cls: 4.714e-05  loss_rpn_loc: 0.006082     lr: 0.00025  max_mem: 1805M
# Loss has not improved for 100 iterations
# [04/27 06:01:43 d2.utils.events]:  eta: 0:41:49  iter: 3419  total_loss: 0.1382  loss_cls: 0.02368  loss_box_reg: 0.03343  loss_mask: 0.08251  loss_rpn_cls: 0.0001451  loss_rpn_loc: 0.006186     lr: 0.00025  max_mem: 1805M
# [04/27 06:01:50 d2.utils.events]:  eta: 0:40:27  iter: 3439  total_loss: 0.1691  loss_cls: 0.03186  loss_box_reg: 0.03231  loss_mask: 0.09059  loss_rpn_cls: 0.0002837  loss_rpn_loc: 0.00534     lr: 0.00025  max_mem: 1805M
# [04/27 06:01:58 d2.utils.events]:  eta: 0:42:04  iter: 3459  total_loss: 0.1389  loss_cls: 0.02193  loss_box_reg: 0.03293  loss_mask: 0.07932  loss_rpn_cls: 9.406e-05  loss_rpn_loc: 0.004055     lr: 0.00025  max_mem: 1805M
# [04/27 06:02:06 d2.utils.events]:  eta: 0:41:32  iter: 3479  total_loss: 0.1885  loss_cls: 0.0271  loss_box_reg: 0.03399  loss_mask: 0.09718  loss_rpn_cls: 9.247e-05  loss_rpn_loc: 0.007748     lr: 0.00025  max_mem: 1805M
# [04/27 06:02:13 d2.utils.events]:  eta: 0:40:43  iter: 3499  total_loss: 0.1964  loss_cls: 0.02815  loss_box_reg: 0.04492  loss_mask: 0.1076  loss_rpn_cls: 0.0007882  loss_rpn_loc: 0.007108     lr: 0.00025  max_mem: 1805M
# Loss has not improved for 200 iterations
# [04/27 06:02:21 d2.utils.events]:  eta: 0:40:53  iter: 3519  total_loss: 0.1567  loss_cls: 0.02254  loss_box_reg: 0.03487  loss_mask: 0.09302  loss_rpn_cls: 0.0004657  loss_rpn_loc: 0.007266     lr: 0.00025  max_mem: 1805M
# [04/27 06:02:28 d2.utils.events]:  eta: 0:41:07  iter: 3539  total_loss: 0.1342  loss_cls: 0.01908  loss_box_reg: 0.0294  loss_mask: 0.07048  loss_rpn_cls: 7.814e-05  loss_rpn_loc: 0.005004     lr: 0.00025  max_mem: 1805M
# [04/27 06:02:36 d2.utils.events]:  eta: 0:40:55  iter: 3559  total_loss: 0.1576  loss_cls: 0.02405  loss_box_reg: 0.03442  loss_mask: 0.09181  loss_rpn_cls: 0.0001509  loss_rpn_loc: 0.005176     lr: 0.00025  max_mem: 1805M
# [04/27 06:02:44 d2.utils.events]:  eta: 0:41:23  iter: 3579  total_loss: 0.1958  loss_cls: 0.02472  loss_box_reg: 0.04302  loss_mask: 0.1001  loss_rpn_cls: 0.0006184  loss_rpn_loc: 0.005794     lr: 0.00025  max_mem: 1822M
# [04/27 06:02:51 d2.utils.events]:  eta: 0:39:17  iter: 3599  total_loss: 0.1773  loss_cls: 0.02811  loss_box_reg: 0.0355  loss_mask: 0.09936  loss_rpn_cls: 0.0002172  loss_rpn_loc: 0.006099     lr: 0.00025  max_mem: 1822M
# Loss has not improved for 300 iterations
# [04/27 06:02:59 d2.utils.events]:  eta: 0:41:02  iter: 3619  total_loss: 0.1528  loss_cls: 0.02151  loss_box_reg: 0.04047  loss_mask: 0.09082  loss_rpn_cls: 6.003e-05  loss_rpn_loc: 0.00592     lr: 0.00025  max_mem: 1822M
# [04/27 06:03:06 d2.utils.events]:  eta: 0:38:44  iter: 3639  total_loss: 0.1632  loss_cls: 0.02026  loss_box_reg: 0.03771  loss_mask: 0.0952  loss_rpn_cls: 0.00012  loss_rpn_loc: 0.005556     lr: 0.00025  max_mem: 1822M
# [04/27 06:03:13 d2.utils.events]:  eta: 0:38:46  iter: 3659  total_loss: 0.1374  loss_cls: 0.01879  loss_box_reg: 0.02955  loss_mask: 0.08356  loss_rpn_cls: 0.0001815  loss_rpn_loc: 0.007319     lr: 0.00025  max_mem: 1822M
# [04/27 06:03:21 d2.utils.events]:  eta: 0:40:21  iter: 3679  total_loss: 0.1759  loss_cls: 0.02618  loss_box_reg: 0.03351  loss_mask: 0.08619  loss_rpn_cls: 0.0001235  loss_rpn_loc: 0.006642     lr: 0.00025  max_mem: 1822M
# [04/27 06:03:28 d2.utils.events]:  eta: 0:38:40  iter: 3699  total_loss: 0.1906  loss_cls: 0.02306  loss_box_reg: 0.04428  loss_mask: 0.09977  loss_rpn_cls: 0.0003574  loss_rpn_loc: 0.005373     lr: 0.00025  max_mem: 1822M
# [04/27 06:03:36 d2.utils.events]:  eta: 0:39:58  iter: 3719  total_loss: 0.1309  loss_cls: 0.0236  loss_box_reg: 0.03079  loss_mask: 0.07873  loss_rpn_cls: 5.98e-05  loss_rpn_loc: 0.004314     lr: 0.00025  max_mem: 1822M
# [04/27 06:03:43 d2.utils.events]:  eta: 0:38:48  iter: 3739  total_loss: 0.1445  loss_cls: 0.02192  loss_box_reg: 0.03774  loss_mask: 0.07892  loss_rpn_cls: 5.504e-05  loss_rpn_loc: 0.005213     lr: 0.00025  max_mem: 1822M
# [04/27 06:03:51 d2.utils.events]:  eta: 0:41:22  iter: 3759  total_loss: 0.157  loss_cls: 0.02431  loss_box_reg: 0.03313  loss_mask: 0.09416  loss_rpn_cls: 0.0001583  loss_rpn_loc: 0.005601     lr: 0.00025  max_mem: 1822M
# [04/27 06:03:59 d2.utils.events]:  eta: 0:40:32  iter: 3779  total_loss: 0.1549  loss_cls: 0.02354  loss_box_reg: 0.034  loss_mask: 0.08852  loss_rpn_cls: 0.0002161  loss_rpn_loc: 0.005088     lr: 0.00025  max_mem: 1822M
# Loss has not improved for 100 iterations
# [04/27 06:04:07 d2.utils.events]:  eta: 0:40:01  iter: 3799  total_loss: 0.1385  loss_cls: 0.02148  loss_box_reg: 0.03595  loss_mask: 0.08649  loss_rpn_cls: 0.0001074  loss_rpn_loc: 0.004643     lr: 0.00025  max_mem: 1876M
# [04/27 06:04:15 d2.utils.events]:  eta: 0:39:46  iter: 3819  total_loss: 0.1513  loss_cls: 0.01842  loss_box_reg: 0.03195  loss_mask: 0.08269  loss_rpn_cls: 0.0002198  loss_rpn_loc: 0.007065     lr: 0.00025  max_mem: 1876M
# [04/27 06:04:22 d2.utils.events]:  eta: 0:38:49  iter: 3839  total_loss: 0.1869  loss_cls: 0.02437  loss_box_reg: 0.04377  loss_mask: 0.1194  loss_rpn_cls: 0.0001325  loss_rpn_loc: 0.007357     lr: 0.00025  max_mem: 1904M
# [04/27 06:04:30 d2.utils.events]:  eta: 0:40:11  iter: 3859  total_loss: 0.1335  loss_cls: 0.02331  loss_box_reg: 0.0338  loss_mask: 0.07735  loss_rpn_cls: 6.326e-05  loss_rpn_loc: 0.00494     lr: 0.00025  max_mem: 1904M
# [04/27 06:04:38 d2.utils.events]:  eta: 0:40:31  iter: 3879  total_loss: 0.1385  loss_cls: 0.0219  loss_box_reg: 0.03742  loss_mask: 0.07931  loss_rpn_cls: 0.0001928  loss_rpn_loc: 0.005857     lr: 0.00025  max_mem: 1904M
# Loss has not improved for 200 iterations
# [04/27 06:04:46 d2.utils.events]:  eta: 0:38:49  iter: 3899  total_loss: 0.1409  loss_cls: 0.0198  loss_box_reg: 0.03867  loss_mask: 0.07417  loss_rpn_cls: 0.0001967  loss_rpn_loc: 0.006193     lr: 0.00025  max_mem: 1904M
# [04/27 06:04:53 d2.utils.events]:  eta: 0:37:38  iter: 3919  total_loss: 0.1499  loss_cls: 0.02299  loss_box_reg: 0.03803  loss_mask: 0.0752  loss_rpn_cls: 0.0003039  loss_rpn_loc: 0.005644     lr: 0.00025  max_mem: 1904M
# ...
# [04/27 06:07:03 d2.utils.events]:  eta: 0:37:01  iter: 4259  total_loss: 0.1399  loss_cls: 0.01927  loss_box_reg: 0.03273  loss_mask: 0.07319  loss_rpn_cls: 4.946e-05  loss_rpn_loc: 0.00532     lr: 0.00025  max_mem: 1904M
# [04/27 06:07:10 d2.utils.events]:  eta: 0:35:35  iter: 4279  total_loss: 0.1489  loss_cls: 0.01888  loss_box_reg: 0.03068  loss_mask: 0.08299  loss_rpn_cls: 0.000148  loss_rpn_loc: 0.00556     lr: 0.00025  max_mem: 1904M
# [04/27 06:07:19 d2.utils.events]:  eta: 0:40:26  iter: 4299  total_loss: 0.1752  loss_cls: 0.02331  loss_box_reg: 0.0374  loss_mask: 0.09916  loss_rpn_cls: 0.0003066  loss_rpn_loc: 0.0063     lr: 0.00025  max_mem: 1904M
# Loss has not improved for 300 iterations
# [04/27 06:07:26 d2.utils.events]:  eta: 0:34:35  iter: 4319  total_loss: 0.1548  loss_cls: 0.01907  loss_box_reg: 0.03086  loss_mask: 0.08534  loss_rpn_cls: 0.0001891  loss_rpn_loc: 0.005395     lr: 0.00025  max_mem: 1904M
# [04/27 06:07:34 d2.utils.events]:  eta: 0:36:50  iter: 4339  total_loss: 0.132  loss_cls: 0.01792  loss_box_reg: 0.02628  loss_mask: 0.07982  loss_rpn_cls: 8.912e-05  loss_rpn_loc: 0.005475     lr: 0.00025  max_mem: 1904M
# [04/27 06:07:42 d2.utils.events]:  eta: 0:36:34  iter: 4359  total_loss: 0.1406  loss_cls: 0.01839  loss_box_reg: 0.02874  loss_mask: 0.08901  loss_rpn_cls: 0.0001817  loss_rpn_loc: 0.005287     lr: 0.00025  max_mem: 1904M
# [04/27 06:07:49 d2.utils.events]:  eta: 0:36:16  iter: 4379  total_loss: 0.1319  loss_cls: 0.02075  loss_box_reg: 0.0343  loss_mask: 0.08033  loss_rpn_cls: 0.0001881  loss_rpn_loc: 0.005363     lr: 0.00025  max_mem: 1904M
# [04/27 06:07:57 d2.utils.events]:  eta: 0:36:03  iter: 4399  total_loss: 0.1485  loss_cls: 0.02076  loss_box_reg: 0.0423  loss_mask: 0.08577  loss_rpn_cls: 0.0001432  loss_rpn_loc: 0.004409     lr: 0.00025  max_mem: 1904M
# [04/27 06:08:04 d2.utils.events]:  eta: 0:34:45  iter: 4419  total_loss: 0.1264  loss_cls: 0.01805  loss_box_reg: 0.02602  loss_mask: 0.07404  loss_rpn_cls: 0.0001793  loss_rpn_loc: 0.004535     lr: 0.00025  max_mem: 1904M
# [04/27 06:08:12 d2.utils.events]:  eta: 0:34:00  iter: 4439  total_loss: 0.1259  loss_cls: 0.01943  loss_box_reg: 0.0299  loss_mask: 0.06815  loss_rpn_cls: 6.494e-05  loss_rpn_loc: 0.004925     lr: 0.00025  max_mem: 1904M
# [04/27 06:08:19 d2.utils.events]:  eta: 0:35:23  iter: 4459  total_loss: 0.1575  loss_cls: 0.02317  loss_box_reg: 0.03049  loss_mask: 0.08955  loss_rpn_cls: 0.0001387  loss_rpn_loc: 0.005378     lr: 0.00025  max_mem: 1904M
# Loss has not improved for 100 iterations
# [04/27 06:08:27 d2.utils.events]:  eta: 0:36:30  iter: 4479  total_loss: 0.1868  loss_cls: 0.02399  loss_box_reg: 0.04345  loss_mask: 0.09919  loss_rpn_cls: 0.000339  loss_rpn_loc: 0.006119     lr: 0.00025  max_mem: 1904M
# [04/27 06:08:35 d2.utils.events]:  eta: 0:35:32  iter: 4499  total_loss: 0.1501  loss_cls: 0.01783  loss_box_reg: 0.03176  loss_mask: 0.08496  loss_rpn_cls: 6.733e-05  loss_rpn_loc: 0.004922     lr: 0.00025  max_mem: 1904M
# [04/27 06:08:42 d2.utils.events]:  eta: 0:33:21  iter: 4519  total_loss: 0.1284  loss_cls: 0.01965  loss_box_reg: 0.03144  loss_mask: 0.07502  loss_rpn_cls: 0.0006983  loss_rpn_loc: 0.004889     lr: 0.00025  max_mem: 1904M
# [04/27 06:08:50 d2.utils.events]:  eta: 0:34:42  iter: 4539  total_loss: 0.1437  loss_cls: 0.01646  loss_box_reg: 0.02624  loss_mask: 0.08023  loss_rpn_cls: 0.0001765  loss_rpn_loc: 0.007711     lr: 0.00025  max_mem: 1904M
# [04/27 06:08:58 d2.utils.events]:  eta: 0:35:47  iter: 4559  total_loss: 0.1537  loss_cls: 0.02003  loss_box_reg: 0.03761  loss_mask: 0.08466  loss_rpn_cls: 0.0001904  loss_rpn_loc: 0.005486     lr: 0.00025  max_mem: 1904M
# [04/27 06:09:06 d2.utils.events]:  eta: 0:35:07  iter: 4579  total_loss: 0.1236  loss_cls: 0.01891  loss_box_reg: 0.03006  loss_mask: 0.07723  loss_rpn_cls: 0.000101  loss_rpn_loc: 0.004776     lr: 0.00025  max_mem: 1904M
# [04/27 06:09:14 d2.utils.events]:  eta: 0:35:13  iter: 4599  total_loss: 0.1189  loss_cls: 0.01659  loss_box_reg: 0.02872  loss_mask: 0.06506  loss_rpn_cls: 0.0002601  loss_rpn_loc: 0.005484     lr: 0.00025  max_mem: 1904M
# Loss has not improved for 100 iterations
# [04/27 06:09:21 d2.utils.events]:  eta: 0:33:59  iter: 4619  total_loss: 0.1327  loss_cls: 0.01655  loss_box_reg: 0.02858  loss_mask: 0.07565  loss_rpn_cls: 4.122e-05  loss_rpn_loc: 0.005276     lr: 0.00025  max_mem: 1904M
# [04/27 06:09:29 d2.utils.events]:  eta: 0:34:28  iter: 4639  total_loss: 0.1368  loss_cls: 0.02022  loss_box_reg: 0.0311  loss_mask: 0.08308  loss_rpn_cls: 4.449e-05  loss_rpn_loc: 0.005821     lr: 0.00025  max_mem: 1904M
# [04/27 06:09:36 d2.utils.events]:  eta: 0:33:12  iter: 4659  total_loss: 0.1494  loss_cls: 0.01931  loss_box_reg: 0.03374  loss_mask: 0.07787  loss_rpn_cls: 0.0002983  loss_rpn_loc: 0.005962     lr: 0.00025  max_mem: 1904M
# [04/27 06:09:44 d2.utils.events]:  eta: 0:33:52  iter: 4679  total_loss: 0.1378  loss_cls: 0.01864  loss_box_reg: 0.02807  loss_mask: 0.07619  loss_rpn_cls: 7.233e-05  loss_rpn_loc: 0.004902     lr: 0.00025  max_mem: 1904M
# [04/27 06:09:52 d2.utils.events]:  eta: 0:33:46  iter: 4699  total_loss: 0.1326  loss_cls: 0.01925  loss_box_reg: 0.03413  loss_mask: 0.08162  loss_rpn_cls: 0.0001306  loss_rpn_loc: 0.00357     lr: 0.00025  max_mem: 1904M
# Loss has not improved for 200 iterations
# [04/27 06:09:59 d2.utils.events]:  eta: 0:33:19  iter: 4719  total_loss: 0.1628  loss_cls: 0.01861  loss_box_reg: 0.03155  loss_mask: 0.08662  loss_rpn_cls: 0.0001099  loss_rpn_loc: 0.007346     lr: 0.00025  max_mem: 1904M
# [04/27 06:10:07 d2.utils.events]:  eta: 0:33:39  iter: 4739  total_loss: 0.1415  loss_cls: 0.01656  loss_box_reg: 0.03297  loss_mask: 0.08433  loss_rpn_cls: 0.0002211  loss_rpn_loc: 0.005566     lr: 0.00025  max_mem: 1904M
# [04/27 06:10:14 d2.utils.events]:  eta: 0:33:04  iter: 4759  total_loss: 0.125  loss_cls: 0.02563  loss_box_reg: 0.03505  loss_mask: 0.06128  loss_rpn_cls: 0.0001289  loss_rpn_loc: 0.006582     lr: 0.00025  max_mem: 1989M
# [04/27 06:10:22 d2.utils.events]:  eta: 0:33:27  iter: 4779  total_loss: 0.1734  loss_cls: 0.02549  loss_box_reg: 0.04745  loss_mask: 0.08965  loss_rpn_cls: 0.0001621  loss_rpn_loc: 0.00471     lr: 0.00025  max_mem: 1989M
# [04/27 06:10:30 d2.utils.events]:  eta: 0:34:07  iter: 4799  total_loss: 0.1261  loss_cls: 0.01604  loss_box_reg: 0.02914  loss_mask: 0.08232  loss_rpn_cls: 0.0002138  loss_rpn_loc: 0.005546     lr: 0.00025  max_mem: 1989M
# Loss has not improved for 300 iterations
# [04/27 06:10:38 d2.utils.events]:  eta: 0:34:20  iter: 4819  total_loss: 0.124  loss_cls: 0.01618  loss_box_reg: 0.02747  loss_mask: 0.07468  loss_rpn_cls: 0.000281  loss_rpn_loc: 0.005356     lr: 0.00025  max_mem: 1989M
# [04/27 06:10:46 d2.utils.events]:  eta: 0:32:52  iter: 4839  total_loss: 0.1319  loss_cls: 0.01707  loss_box_reg: 0.02719  loss_mask: 0.07973  loss_rpn_cls: 0.00014  loss_rpn_loc: 0.004224     lr: 0.00025  max_mem: 1989M
# [04/27 06:10:53 d2.utils.events]:  eta: 0:32:48  iter: 4859  total_loss: 0.1362  loss_cls: 0.02077  loss_box_reg: 0.03251  loss_mask: 0.0851  loss_rpn_cls: 5.066e-05  loss_rpn_loc: 0.004305     lr: 0.00025  max_mem: 1989M
# [04/27 06:11:01 d2.utils.events]:  eta: 0:33:23  iter: 4879  total_loss: 0.1205  loss_cls: 0.01929  loss_box_reg: 0.0285  loss_mask: 0.06718  loss_rpn_cls: 0.0001179  loss_rpn_loc: 0.004613     lr: 0.00025  max_mem: 1989M
# [04/27 06:11:09 d2.utils.events]:  eta: 0:32:30  iter: 4899  total_loss: 0.1757  loss_cls: 0.02127  loss_box_reg: 0.03796  loss_mask: 0.1034  loss_rpn_cls: 0.0002611  loss_rpn_loc: 0.005536     lr: 0.00025  max_mem: 1989M
# Loss has not improved for 400 iterations
# [04/27 06:11:17 d2.utils.events]:  eta: 0:34:05  iter: 4919  total_loss: 0.1734  loss_cls: 0.02278  loss_box_reg: 0.05302  loss_mask: 0.09342  loss_rpn_cls: 0.0003665  loss_rpn_loc: 0.005881     lr: 0.00025  max_mem: 1989M
# [04/27 06:11:24 d2.utils.events]:  eta: 0:32:08  iter: 4939  total_loss: 0.1286  loss_cls: 0.01885  loss_box_reg: 0.03196  loss_mask: 0.07174  loss_rpn_cls: 9.821e-05  loss_rpn_loc: 0.006163     lr: 0.00025  max_mem: 1989M
# [04/27 06:11:32 d2.utils.events]:  eta: 0:30:56  iter: 4959  total_loss: 0.1304  loss_cls: 0.01746  loss_box_reg: 0.03014  loss_mask: 0.0777  loss_rpn_cls: 8.56e-05  loss_rpn_loc: 0.00441     lr: 0.00025  max_mem: 1989M
# [04/27 06:11:39 d2.utils.events]:  eta: 0:32:04  iter: 4979  total_loss: 0.125  loss_cls: 0.02147  loss_box_reg: 0.03133  loss_mask: 0.07213  loss_rpn_cls: 7.001e-05  loss_rpn_loc: 0.006354     lr: 0.00025  max_mem: 1989M
# [04/27 06:11:47 d2.utils.events]:  eta: 0:31:55  iter: 4999  total_loss: 0.1299  loss_cls: 0.0176  loss_box_reg: 0.02845  loss_mask: 0.07919  loss_rpn_cls: 2.739e-05  loss_rpn_loc: 0.003751     lr: 0.00025  max_mem: 1989M
# Loss has not improved for 500 iterations
# EARLY STOPPING
# WARNING [04/27 06:11:52 d2.data.datasets.coco]:
# Category ids in annotations are not in [1, #categories]! We'll apply a mapping for you.
#
# [04/27 06:11:52 d2.data.datasets.coco]: Loaded 12 images in COCO format from /content/test/_annotations.coco.json
# [04/27 06:11:52 d2.data.build]: Distribution of instances among all 3 categories:
# |  category  | #instances   |  category  | #instances   |  category  | #instances   |
# |:----------:|:-------------|:----------:|:-------------|:----------:|:-------------|
# | spoon-fox  | 0            |    fox     | 13           |   spoon    | 4            |
# |            |              |            |              |            |              |
# |   total    | 17           |            |              |            |              |
# [04/27 06:11:52 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [04/27 06:11:52 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [04/27 06:11:52 d2.data.common]: Serializing 12 elements to byte tensors and concatenating them all ...
# [04/27 06:11:52 d2.data.common]: Serialized dataset takes 0.01 MiB
# [04/27 06:11:52 d2.evaluation.evaluator]: Start inference on 12 batches
# [04/27 06:11:53 d2.evaluation.evaluator]: Inference done 11/12. Dataloading: 0.0014 s/iter. Inference: 0.0842 s/iter. Eval: 0.0037 s/iter. Total: 0.0893 s/iter. ETA=0:00:00
# [04/27 06:11:53 d2.evaluation.evaluator]: Total inference time: 0:00:00.655125 (0.093589 s / iter per device, on 1 devices)
# [04/27 06:11:53 d2.evaluation.evaluator]: Total inference pure compute time: 0:00:00 (0.083449 s / iter per device, on 1 devices)
# [04/27 06:11:53 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [04/27 06:11:53 d2.evaluation.coco_evaluation]: Saving results to ./output/inference/asl_poly_test/coco_instances_results.json
# [04/27 06:11:53 d2.evaluation.coco_evaluation]: Evaluating predictions with unofficial COCO API...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# [04/27 06:11:53 d2.evaluation.fast_eval_api]: Evaluate annotation type *bbox*
# [04/27 06:11:53 d2.evaluation.fast_eval_api]: COCOeval_opt.evaluate() finished in 0.01 seconds.
# [04/27 06:11:53 d2.evaluation.fast_eval_api]: Accumulating evaluation results...
# [04/27 06:11:53 d2.evaluation.fast_eval_api]: COCOeval_opt.accumulate() finished in 0.01 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.630
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.765
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.742
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.700
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.477
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.676
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.620
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.713
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.713
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.700
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.567
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.713
# [04/27 06:11:53 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs   |  APm   |  APl   |
# |:------:|:------:|:------:|:------:|:------:|:------:|
# | 62.974 | 76.494 | 74.184 | 70.000 | 47.723 | 67.554 |
# [04/27 06:11:53 d2.evaluation.coco_evaluation]: Per-category bbox AP:
# | category   | AP   | category   | AP     | category   | AP     |
# |:-----------|:-----|:-----------|:-------|:-----------|:-------|
# | spoon-fox  | nan  | fox        | 53.175 | spoon      | 72.772 |
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# [04/27 06:11:53 d2.evaluation.fast_eval_api]: Evaluate annotation type *segm*
# [04/27 06:11:53 d2.evaluation.fast_eval_api]: COCOeval_opt.evaluate() finished in 0.01 seconds.
# [04/27 06:11:53 d2.evaluation.fast_eval_api]: Accumulating evaluation results...
# [04/27 06:11:53 d2.evaluation.fast_eval_api]: COCOeval_opt.accumulate() finished in 0.01 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.481
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.742
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.575
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.700
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.388
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.515
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.465
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.546
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.546
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.700
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.467
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.539
# [04/27 06:11:53 d2.evaluation.coco_evaluation]: Evaluation results for segm:
# |   AP   |  AP50  |  AP75  |  APs   |  APm   |  APl   |
# |:------:|:------:|:------:|:------:|:------:|:------:|
# | 48.085 | 74.184 | 57.501 | 70.000 | 38.812 | 51.472 |
# [04/27 06:11:53 d2.evaluation.coco_evaluation]: Per-category segm AP:
# | category   | AP   | category   | AP     | category   | AP     |
# |:-----------|:-----|:-----------|:-------|:-----------|:-------|
# | spoon-fox  | nan  | fox        | 43.809 | spoon      | 52.360 |
# [04/27 06:11:53 detectron2]: Evaluation results for asl_poly_test in csv format:
# [04/27 06:11:53 d2.evaluation.testing]: copypaste: Task: bbox
# [04/27 06:11:53 d2.evaluation.testing]: copypaste: AP,AP50,AP75,APs,APm,APl
# [04/27 06:11:53 d2.evaluation.testing]: copypaste: 62.9736,76.4939,74.1837,70.0000,47.7228,67.5545
# [04/27 06:11:53 d2.evaluation.testing]: copypaste: Task: segm
# [04/27 06:11:53 d2.evaluation.testing]: copypaste: AP,AP50,AP75,APs,APm,APl
# [04/27 06:11:53 d2.evaluation.testing]: copypaste: 48.0846,74.1837,57.5008,70.0000,38.8119,51.4721
# OrderedDict([('bbox',
#               {'AP': 62.97358307259297,
#                'AP50': 76.493899389939,
#                'AP75': 74.18366836683668,
#                'APs': 70.0,
#                'APm': 47.72277227722772,
#                'APl': 67.55445544554455,
#                'AP-spoon-fox': nan,
#                'AP-fox': 53.17488891746318,
#                'AP-spoon': 72.77227722772277}),
#              ('segm',
#               {'AP': 48.08455845584558,
#                'AP50': 74.18366836683668,
#                'AP75': 57.5007500750075,
#                'APs': 70.0,
#                'APm': 38.81188118811881,
#                'APl': 51.47206506364922,
#                'AP-spoon-fox': nan,
#                'AP-fox': 43.80938093809381,
#                'AP-spoon': 52.35973597359735})])

# %% [markdown]
# ## Test model and show example output

# %%
cfg.MODEL.WEIGHTS = os.path.join(cfg.OUTPUT_DIR, "model_0004999.pth")  # path to the model we just trained
cfg.MODEL.ROI_HEADS.SCORE_THRESH_TEST = 0.2   # set a custom testing threshold
predictor = DefaultPredictor(cfg)

dataset_dicts = DatasetCatalog.get("asl_poly_valid")
for d in random.sample(dataset_dicts, 3):    
    im = cv2.imread(d["file_name"])
    outputs = predictor(im)
    v = Visualizer(im[:, :, ::-1],
                   scale=0.5, 
                   instance_mode=ColorMode.IMAGE_BW
    )
    out = v.draw_instance_predictions(outputs["instances"].to("cpu"))
    im = Image.fromarray(out.get_image()[:, :, ::-1])
    im
# Out:
# [04/27 06:13:15 d2.checkpoint.detection_checkpoint]: [DetectionCheckpointer] Loading from ./output/model_0004999.pth ...
# WARNING [04/27 06:13:15 d2.data.datasets.coco]:
# Category ids in annotations are not in [1, #categories]! We'll apply a mapping for you.
#
# [04/27 06:13:15 d2.data.datasets.coco]: Loaded 21 images in COCO format from /content/valid/_annotations.coco.json

# %%
im
# Out:
# <PIL.Image.Image image mode=RGB size=320x320 at 0x7F5B2D82EDF0>

# %% [markdown]
# # Yolov8

# %%
import locale
locale.getpreferredencoding = lambda: "UTF-8"

# %%
# !pip install ultralytics==8.0.28

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.28 🚀 Python-3.9.16 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 23.9/78.2 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
# !mkdir datasets
# %cd /content/datasets
# !curl -L "https://app.roboflow.com/ds/Md710th8GI?key=8eJSxxg2XF" > roboflow.zip; unzip roboflow.zip; rm roboflow.zip
# %cd ..

# %%
# !yolo task=segment mode=train model=yolov8s-seg.pt data=/content/datasets/data.yaml epochs=24 plots=True
# Out:
# Ultralytics YOLOv8.0.28 🚀 Python-3.9.16 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# yolo/engine/trainer: task=segment, mode=train, model=yolov8s-seg.pt, data=/content/datasets/data.yaml, epochs=24, patience=50, batch=16, imgsz=640, save=True, cache=False, device=None, workers=8, project=None, name=None, exist_ok=False, pretrained=False, optimizer=SGD, verbose=True, seed=0, deterministic=True, single_cls=False, image_weights=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, show=False, save_txt=False, save_conf=False, save_crop=False, hide_labels=False, hide_conf=False, vid_stride=1, line_thickness=3, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, boxes=True, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, fl_gamma=0.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, cfg=None, v5loader=False, save_dir=runs/segment/train2
# 2023-04-27 06:25:42.956072: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Overriding model.yaml nc=80 with nc=2
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.Conv                  [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.Conv                  [32, 64, 3, 2]
#   2                  -1  1     29056  ultralytics.nn.modules.C2f                   [64, 64, 1, True]
#   3                  -1  1     73984  ultralytics.nn.modules.Conv                  [64, 128, 3, 2]
#   4                  -1  2    197632  ultralytics.nn.modules.C2f                   [128, 128, 2, True]
#   5                  -1  1    295424  ultralytics.nn.modules.Conv                  [128, 256, 3, 2]
#   6                  -1  2    788480  ultralytics.nn.modules.C2f                   [256, 256, 2, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.Conv                  [256, 512, 3, 2]
#   8                  -1  1   1838080  ultralytics.nn.modules.C2f                   [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.SPPF                  [512, 512, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.Concat                [1]
#  12                  -1  1    591360  ultralytics.nn.modules.C2f                   [768, 256, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.Concat                [1]
#  15                  -1  1    148224  ultralytics.nn.modules.C2f                   [384, 128, 1]
#  16                  -1  1    147712  ultralytics.nn.modules.Conv                  [128, 128, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.Concat                [1]
#  18                  -1  1    493056  ultralytics.nn.modules.C2f                   [384, 256, 1]
#  19                  -1  1    590336  ultralytics.nn.modules.Conv                  [256, 256, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.Concat                [1]
#  21                  -1  1   1969152  ultralytics.nn.modules.C2f                   [768, 512, 1]
#  22        [15, 18, 21]  1   2771318  ultralytics.nn.modules.Segment               [2, 32, 128, [128, 256, 512]]
# YOLOv8s-seg summary: 261 layers, 11790870 parameters, 11790854 gradients, 42.7 GFLOPs
#
# Transferred 411/417 items from pretrained weights
# optimizer: SGD(lr=0.01) with parameter groups 66 weight(decay=0.0), 77 weight(decay=0.0005), 76 bias
# train: Scanning /content/datasets/train/labels.cache... 219 images, 0 backgrounds, 0 corrupt: 100% 219/219 [00:00<?, ?it/s]
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# val: Scanning /content/datasets/valid/labels.cache... 21 images, 0 backgrounds, 0 corrupt: 100% 21/21 [00:00<?, ?it/s]
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to runs/segment/train2
# Starting training for 24 epochs...
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#        1/24      4.86G       1.64      3.644       4.86      1.597         34        640: 100% 14/14 [00:14<00:00,  1.06s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  1.26it/s]
#                    all         21         36      0.241      0.105      0.079     0.0381      0.217      0.162     0.0734     0.0414
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#        2/24      5.41G      1.348      2.763      3.145      1.414         40        640: 100% 14/14 [00:12<00:00,  1.15it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  1.51it/s]
#                    all         21         36      0.381      0.367       0.24      0.136      0.342      0.333      0.224     0.0982
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#        3/24      5.41G      1.098      2.291      2.296      1.236         26        640: 100% 14/14 [00:11<00:00,  1.18it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  1.46it/s]
#                    all         21         36       0.59      0.199      0.256      0.187      0.432      0.233      0.266       0.13
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#        4/24      5.41G      1.011      1.835      1.865      1.141         39        640: 100% 14/14 [00:13<00:00,  1.05it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  1.55it/s]
#                    all         21         36      0.521      0.281      0.262      0.187      0.521      0.281      0.269      0.148
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#        5/24      5.41G     0.9971      1.667      1.834      1.118         21        640: 100% 14/14 [00:11<00:00,  1.21it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  1.54it/s]
#                    all         21         36      0.413      0.467      0.386      0.275      0.413      0.467      0.386      0.228
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#        6/24      5.41G      1.013      1.712      1.656      1.103         24        640: 100% 14/14 [00:11<00:00,  1.17it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  1.57it/s]
#                    all         21         36      0.714      0.424      0.489      0.348      0.714      0.424      0.481       0.32
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#        7/24      5.41G     0.8774      1.434      1.307      1.022         36        640: 100% 14/14 [00:11<00:00,  1.20it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  1.56it/s]
#                    all         21         36      0.632      0.511      0.539      0.394      0.689      0.465      0.532      0.357
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#        8/24      5.41G     0.9667      1.538      1.308       1.05         26        640: 100% 14/14 [00:11<00:00,  1.19it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  1.53it/s]
#                    all         21         36       0.61      0.569      0.588      0.432      0.639      0.559      0.583      0.377
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#        9/24      5.42G     0.9067      1.365      1.147      1.033         23        640: 100% 14/14 [00:11<00:00,  1.21it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  1.57it/s]
#                    all         21         36       0.76      0.471      0.597      0.424       0.76      0.471      0.579      0.349
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       10/24      5.42G     0.9679      1.602      1.212       1.09         34        640: 100% 14/14 [00:11<00:00,  1.21it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  1.53it/s]
#                    all         21         36      0.692       0.46      0.515      0.375      0.658      0.488      0.527      0.278
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       11/24      5.42G     0.9097        1.5      1.093      1.043         29        640: 100% 14/14 [00:11<00:00,  1.22it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  1.41it/s]
#                    all         21         36      0.513      0.514      0.517       0.33      0.513      0.514      0.496      0.292
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       12/24      5.42G     0.8874      1.366      1.008      1.042         24        640: 100% 14/14 [00:10<00:00,  1.31it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  1.17it/s]
#                    all         21         36       0.71      0.324      0.367      0.245      0.677      0.293      0.342      0.176
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       13/24      5.42G     0.8859      1.501     0.9861      1.005         33        640: 100% 14/14 [00:10<00:00,  1.37it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  1.15it/s]
#                    all         21         36       0.58      0.433      0.503       0.29      0.636      0.457      0.542      0.276
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       14/24      5.42G     0.8397      1.376     0.9422      1.008         18        640: 100% 14/14 [00:10<00:00,  1.30it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  1.59it/s]
#                    all         21         36      0.561      0.562      0.546       0.37      0.561      0.562       0.55      0.325
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       15/24      5.43G     0.8601      1.146     0.8995      1.056         14        640: 100% 14/14 [00:10<00:00,  1.38it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  1.50it/s]
#                    all         21         36      0.835      0.538      0.673      0.454      0.835      0.538      0.687      0.432
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       16/24      5.43G     0.8429      1.158     0.8346      1.053         16        640: 100% 14/14 [00:07<00:00,  1.85it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  1.56it/s]
#                    all         21         36      0.725       0.59      0.686      0.515      0.725       0.59      0.679       0.47
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       17/24      5.43G     0.8346      1.097     0.7669      1.022         17        640: 100% 14/14 [00:06<00:00,  2.29it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  1.20it/s]
#                    all         21         36      0.798      0.657      0.685      0.515      0.798      0.657      0.685      0.485
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       18/24      5.43G     0.8245       1.03     0.7084      1.006         17        640: 100% 14/14 [00:07<00:00,  1.97it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  1.49it/s]
#                    all         21         36      0.693      0.635      0.721      0.503      0.693      0.635      0.724      0.492
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       19/24      5.43G     0.7716      0.974     0.6885      1.012         21        640: 100% 14/14 [00:07<00:00,  1.95it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  1.45it/s]
#                    all         21         36      0.776      0.636      0.722      0.518      0.767       0.66      0.708      0.505
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       20/24      5.43G     0.7345     0.9498     0.6244     0.9711         13        640: 100% 14/14 [00:06<00:00,  2.14it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  1.56it/s]
#                    all         21         36      0.744      0.644      0.714      0.496      0.744      0.644      0.691      0.499
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       21/24      5.43G     0.7015     0.9098     0.5732     0.9569         16        640: 100% 14/14 [00:07<00:00,  1.92it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  1.58it/s]
#                    all         21         36       0.97      0.513      0.787      0.586       0.97      0.513      0.788      0.548
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       22/24      5.43G     0.7313     0.9156     0.5796     0.9873         12        640: 100% 14/14 [00:06<00:00,  2.22it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  1.10it/s]
#                    all         21         36      0.921      0.581      0.791      0.618      0.921      0.581      0.791      0.588
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       23/24      5.43G     0.6931     0.9527     0.5748     0.9554         18        640: 100% 14/14 [00:06<00:00,  2.12it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  1.55it/s]
#                    all         21         36      0.802      0.581      0.776      0.606      0.802      0.581      0.776      0.548
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       24/24      5.43G     0.6458      0.878     0.5065     0.9185         15        640: 100% 14/14 [00:07<00:00,  1.92it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  1.21it/s]
#                    all         21         36      0.751      0.642      0.747      0.585      0.751      0.642      0.754       0.54
#
# 24 epochs completed in 0.078 hours.
# Optimizer stripped from runs/segment/train2/weights/last.pt, 23.8MB
# Optimizer stripped from runs/segment/train2/weights/best.pt, 23.8MB
#
# Validating runs/segment/train2/weights/best.pt...
# Ultralytics YOLOv8.0.28 🚀 Python-3.9.16 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8s-seg summary (fused): 195 layers, 11780374 parameters, 0 gradients, 42.4 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  1.23it/s]
#                    all         21         36      0.919      0.581      0.791      0.618      0.919      0.581      0.791      0.588
#                    fox         21         15      0.868      0.733      0.866      0.659      0.868      0.733      0.866      0.625
#                  spoon         21         21      0.971      0.429      0.717      0.577      0.971      0.429      0.717      0.551
# Speed: 0.2ms pre-process, 7.6ms inference, 0.0ms loss, 0.9ms post-process per image
# Results saved to runs/segment/train2

# %%
Image(filename=f'/content/runs/segment/train/results.png', width=600)

# %%
Image(filename=f'/content/runs/segment/train/val_batch0_pred.jpg', width=600)

# %% [markdown]
# # Comparison
#
# - Mean Average Precision
#   - Mask RCNN: 74.18%
#   - Yolov8: 82.3%
# - Speed:
#   - Yolo is a lot faster and such speed gives a lot of betefits despite its size
#   - Yolo training for 24 epochs done in 4 minutes, but Faster RCNN in 55 minutes
# - Size:
#   - Mask RCNN model size: 335.82 Mb
#   - Yolov8 model size: 22.79 Mb
